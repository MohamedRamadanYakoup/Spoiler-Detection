# %% [markdown]
# > **사용한 데이터셋**
# >
# > IMDB Spoiler Dataset: Can you identify which reviews have spoilers to improve user experience?
# > - Rishabh Misra, 2019. 05. <br/>
# > - doi: 10.13140/RG.2.2.11584.15362 <br/>
# > - https://rishabhmisra.github.io/publications
# >- https://www.kaggle.com/rmisra/imdb-spoiler-dataset?select=IMDB_reviews.json

# %% [markdown]
# ### 1) 데이터 불러오기

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import tensorflow as tf
import random
import os
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

main_seed = 42

np.random.seed(main_seed)
random.seed(main_seed)
tf.random.set_seed(main_seed)

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_path = 'drive/MyDrive/IMDB_Spoiler_Dataset_edit'

# %%
import pickle
import gzip

# 전처리한 파일을 불러오기 위한 함수
def load_data(file_name):
  global base_path
  with gzip.open(os.path.join(base_path, file_name), 'rb') as f:
    return pickle.load(f)

# %%
# 파일 불러오기
print('load X_train...')
X_train = load_data('X_train_word.pickle')
print('load X_val...')
X_val = load_data('X_val_word.pickle')
print('load X_test...')
X_test = load_data('X_test_word.pickle')

print('load y_train...')
y_train = load_data('y_train.pickle')
print('load y_val...')
y_val = load_data('y_val.pickle')
print('load y_test...')
y_test = load_data('y_test.pickle')

print('load embeddings...')
embeddings = load_data('embeddings.pickle')

print('load max_len...')
max_len = load_data('max_len.pickle')
# Out:
# load X_train...
# load X_val...
# load X_test...
# load y_train...
# load y_val...
# load y_test...
# load embeddings...
# load max_len...

# %% [markdown]
# 자주 쓰는 기능 함수로 생성

# %%
# 학습 시 에포크 수에 따른 loss와 accuracy 변화 기록 시각화를 위한 함수
def show_history(model_hist):
  plt.figure(figsize=(10, 5))

  plt.subplot(121)
  plt.plot(model_hist.history['loss'], 'b', label='train')
  plt.plot(model_hist.history['val_loss'], 'g', label='val')
  plt.title('Loss')
  plt.xlabel('epochs')
  plt.ylabel('loss')
  plt.legend(loc='upper right')

  plt.subplot(122)
  plt.plot(model_hist.history['accuracy'], 'b', label='train')
  plt.plot(model_hist.history['val_accuracy'], 'g', label='val')
  plt.title('Accuracy')
  plt.xlabel('epochs')
  plt.ylabel('accuracy')
  plt.legend(loc='upper left')

  plt.show();

# %%
import keras
import keras.backend as K
from keras.layers import Input, Embedding, LSTM, Lambda, concatenate, Dropout, Flatten, Dense, Bidirectional, GRU, Conv1D, GlobalMaxPooling1D, BatchNormalization, MaxPooling1D
from keras.models import Model
from keras import initializers
from sklearn.metrics import accuracy_score, f1_score

np.random.seed(main_seed)
tf.random.set_seed(main_seed)

# %%
# early_stop, save_best 객체 생성을 위한 함수(저장 위치를 drive로)
def set_callbacks(model_name):
  early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0,
    patience=5,
    verbose=2)
  
  base_path = 'drive/MyDrive/IMDB_Spoiler_Dataset_edit'
  file_path = os.path.join(base_path,
                           'model_result',
                           model_name + '_weight.hdf5')
  save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=file_path,
    monitor='val_loss',
    verbose=2,
    save_best_only=True,
    save_weights_only=True,
    mode='auto',
    save_freq='epoch',
    option=None)
  
  return early_stop, save_best, file_path

# %%
# early_stop, save_best 객체 생성을 위한 함수 (저장 위치를 colab으로)
def set_callbacks_ver2(model_name):
  early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0,
    patience=5,
    verbose=2)
  
  file_path = os.path.join(model_name + '_weight.hdf5')
  save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=file_path,
    monitor='val_loss',
    verbose=2,
    save_best_only=True,
    save_weights_only=True,
    mode='auto',
    save_freq='epoch',
    option=None)
  
  return early_stop, save_best, file_path

# %% [markdown]
# ### 2) 가설 검정
#
# >리뷰가 스포일러인지 아닌지 판단하는 이진분류 문제에서는 MaLSTM 모델보다 Siamese Network와 Fully Connected layer를 사용한 모델의 accuracy가 더 높을 것이다.

# %% [markdown]
# #### 기준 모델

# %%
from scipy import stats

# 최빈 클래스 확인
mode_class = stats.mode(y_train)
print(mode_class)
# Out:
# ModeResult(mode=array([0]), count=array([176727]))

# %%
y_pred = [mode_class[0]] * len(y_val)
print('val accuracy:', accuracy_score(y_val, y_pred))
print('val f1_score:', f1_score(y_val, y_pred))
# Out:
# val accuracy: 0.7693211795126284
# val f1_score: 0.0

# %% [markdown]
# 기준 모델의 accuracy는 약 0.7693, f1 score는 0이다.
#
# 스포일러가 아닌 리뷰는 전체의 약 0.77%, 스포일러인 리뷰는 전체의 약 0.23%로 비율 차이가 크다. 따라서 주 분류 성능 평가 지표는 accuracy로 하되, f1 score를 함께 확인하기로 하였다.

# %% [markdown]
# #### 1. MaLSTM
#
# - Mueller, J., & Thyagarajan, A. (2015). Siamese Recurrent Architectures for Learning Sentence Similarity. AAAI-16. Arizona, USA.
#
# - [How to predict Quora Question Pairs using Siamese Manhattan LSTM](https://medium.com/mlreview/implementing-malstm-on-kaggles-quora-question-pairs-competition-8b31b0b16a07) 참고

# %%
# exponent neg manhattan distance 계산
def exponent_neg_manhattan_distance(left, right):
    return K.exp(-K.sum(K.abs(left-right), axis=1, keepdims=True))

# %%
def create_MaLSTM(max_length):

  # summary와 review 각각 입력 받기
  left_input= Input((max_length, ))
  right_input = Input((max_length, ))

  # 임베딩
  embedding_layer = Embedding(len(embeddings),
                              300,
                              weights=[embeddings],
                              input_length=max_length,
                              trainable=False,
                              embeddings_initializer=initializers.glorot_uniform(seed=main_seed))
  left_encoded = embedding_layer(left_input)
  right_encoded = embedding_layer(right_input)

  # lstm
  lstm_layer = LSTM(50,
                    kernel_initializer=initializers.glorot_uniform(seed=main_seed))
  left_output = lstm_layer(left_encoded)
  right_output = lstm_layer(right_encoded)

  # exponent_neg_manhattan_distance 계산 (-> 0 ~ 1 사이의 값)
  distance = Lambda(function = lambda x: exponent_neg_manhattan_distance(x[0], x[1]),
                    output_shape = lambda x: (x[0][0], 1)
                    )([left_output, right_output])

  model = Model([left_input, right_input], [distance])
  return model

# %%
malstm = create_MaLSTM(max_len)

malstm.compile(optimizer='adam',
               loss='mean_squared_error',
               metrics=['accuracy'])

# %%
malstm.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 514, 300)     211276500   input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 50)           70200       embedding[0][0]
#                                                                  embedding[1][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 1)            0           lstm[0][0]
#                                                                  lstm[1][0]
# ==================================================================================================
# Total params: 211,346,700
# Trainable params: 70,200
# Non-trainable params: 211,276,500
# __________________________________________________________________________________________________

# %%
tf.random.set_seed(main_seed)

early_stop, save_best, file_path = set_callbacks('MaLSTM')

malstm_history = malstm.fit(
    [X_train['summary'], X_train['review']],
    y_train,
    batch_size=1024,
    epochs=20,
    validation_data=([X_val['summary'], X_val['review']], y_val),
    callbacks=[save_best, early_stop]);
# Out:
# Epoch 1/20
# 225/225 [==============================] - 97s 408ms/step - loss: 0.1942 - accuracy: 0.7688 - val_loss: 0.1809 - val_accuracy: 0.7687
#
# Epoch 00001: val_loss improved from inf to 0.18090, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/MaLSTM_weight.hdf5
# Epoch 2/20
# 225/225 [==============================] - 90s 399ms/step - loss: 0.1765 - accuracy: 0.7691 - val_loss: 0.1701 - val_accuracy: 0.7685
#
# Epoch 00002: val_loss improved from 0.18090 to 0.17006, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/MaLSTM_weight.hdf5
# Epoch 3/20
# 225/225 [==============================] - 95s 421ms/step - loss: 0.1652 - accuracy: 0.7728 - val_loss: 0.1668 - val_accuracy: 0.7699
#
# Epoch 00003: val_loss improved from 0.17006 to 0.16680, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/MaLSTM_weight.hdf5
# Epoch 4/20
# 225/225 [==============================] - 95s 420ms/step - loss: 0.1627 - accuracy: 0.7746 - val_loss: 0.1653 - val_accuracy: 0.7704
#
# Epoch 00004: val_loss improved from 0.16680 to 0.16528, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/MaLSTM_weight.hdf5
# Epoch 5/20
# 225/225 [==============================] - 95s 422ms/step - loss: 0.1605 - accuracy: 0.7773 - val_loss: 0.1646 - val_accuracy: 0.7696
#
# Epoch 00005: val_loss improved from 0.16528 to 0.16463, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/MaLSTM_weight.hdf5
# Epoch 6/20
# 225/225 [==============================] - 95s 422ms/step - loss: 0.1586 - accuracy: 0.7793 - val_loss: 0.1634 - val_accuracy: 0.7701
#
# Epoch 00006: val_loss improved from 0.16463 to 0.16342, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/MaLSTM_weight.hdf5
# Epoch 7/20
# 225/225 [==============================] - 95s 423ms/step - loss: 0.1572 - accuracy: 0.7813 - val_loss: 0.1625 - val_accuracy: 0.7726
#
# Epoch 00007: val_loss improved from 0.16342 to 0.16247, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/MaLSTM_weight.hdf5
# Epoch 8/20
# 225/225 [==============================] - 95s 422ms/step - loss: 0.1567 - accuracy: 0.7825 - val_loss: 0.1623 - val_accuracy: 0.7731
#
# Epoch 00008: val_loss improved from 0.16247 to 0.16230, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/MaLSTM_weight.hdf5
# Epoch 9/20
# 225/225 [==============================] - 95s 421ms/step - loss: 0.1550 - accuracy: 0.7855 - val_loss: 0.1616 - val_accuracy: 0.7728
#
# Epoch 00009: val_loss improved from 0.16230 to 0.16158, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/MaLSTM_weight.hdf5
# Epoch 10/20
# 225/225 [==============================] - 95s 422ms/step - loss: 0.1532 - accuracy: 0.7884 - val_loss: 0.1641 - val_accuracy: 0.7695
#
# Epoch 00010: val_loss did not improve from 0.16158
# Epoch 11/20
# 225/225 [==============================] - 95s 421ms/step - loss: 0.1540 - accuracy: 0.7880 - val_loss: 0.1609 - val_accuracy: 0.7736
#
# Epoch 00011: val_loss improved from 0.16158 to 0.16086, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/MaLSTM_weight.hdf5
# Epoch 12/20
# 225/225 [==============================] - 95s 421ms/step - loss: 0.1520 - accuracy: 0.7890 - val_loss: 0.1609 - val_accuracy: 0.7758
#
# Epoch 00012: val_loss did not improve from 0.16086
# Epoch 13/20
# 225/225 [==============================] - 86s 382ms/step - loss: 0.1514 - accuracy: 0.7898 - val_loss: 0.1604 - val_accuracy: 0.7746
#
# Epoch 00013: val_loss improved from 0.16086 to 0.16040, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/MaLSTM_weight.hdf5
# Epoch 14/20
# 225/225 [==============================] - 95s 421ms/step - loss: 0.1505 - accuracy: 0.7914 - val_loss: 0.1605 - val_accuracy: 0.7735
#
# Epoch 00014: val_loss did not improve from 0.16040
# Epoch 15/20
# 225/225 [==============================] - 94s 420ms/step - loss: 0.1495 - accuracy: 0.7932 - val_loss: 0.1606 - val_accuracy: 0.7724
#
# Epoch 00015: val_loss did not improve from 0.16040
# Epoch 16/20
# 225/225 [==============================] - 94s 420ms/step - loss: 0.1497 - accuracy: 0.7934 - val_loss: 0.1604 - val_accuracy: 0.7759
#
# Epoch 00016: val_loss did not improve from 0.16040
# Epoch 17/20
# 225/225 [==============================] - 94s 420ms/step - loss: 0.1491 - accuracy: 0.7938 - val_loss: 0.1605 - val_accuracy: 0.7756
#
# Epoch 00017: val_loss did not improve from 0.16040
# Epoch 18/20
# 225/225 [==============================] - 95s 422ms/step - loss: 0.1477 - accuracy: 0.7954 - val_loss: 0.1601 - val_accuracy: 0.7763
#
# Epoch 00018: val_loss improved from 0.16040 to 0.16014, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/MaLSTM_weight.hdf5
# Epoch 19/20
# 225/225 [==============================] - 95s 421ms/step - loss: 0.1473 - accuracy: 0.7968 - val_loss: 0.1609 - val_accuracy: 0.7709
#
# Epoch 00019: val_loss did not improve from 0.16014
# Epoch 20/20
# 225/225 [==============================] - 95s 422ms/step - loss: 0.1477 - accuracy: 0.7958 - val_loss: 0.1601 - val_accuracy: 0.7731
#
# Epoch 00020: val_loss improved from 0.16014 to 0.16012, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/MaLSTM_weight.hdf5

# %%
# validation dataset accuracy, f1_score

# %%time
malstm.load_weights(file_path)
y_pred = malstm.predict([X_val['summary'], X_val['review']])
y_pred_class = np.array([1 if value > 0.5 else 0 for value in y_pred])

print('val accuracy:', accuracy_score(y_val, y_pred_class))
print('val f1_score:', f1_score(y_val, y_pred_class))
# Out:
# val accuracy: 0.7731475435526419
# val f1_score: 0.2635349980921694
# CPU times: user 1min 6s, sys: 5.05 s, total: 1min 11s
# Wall time: 58.7 s

# %% [markdown]
# MaLSTM 모델의 validation 데이터셋에 대한 accuracy는 약 0.7731, f1 score는 약 0.2635이다. 기준 모델의 accuracy(약 0.7693), f1 score(0)보다 높으므로 학습이 잘 된 의미있는 모델이라고 할 수 있다.

# %%
malstm.save(os.path.join(base_path, 'model_result', 'MaLSTM.h5'))
show_history(malstm_history)

# %% [markdown]
# #### 2. 새로 만든 모델 (LSTM + Fully connected layer)

# %%
def create_LSTM_FC(max_length):

  # summary와 review 각각 입력 받기
  left_input= Input((max_length, ))
  right_input = Input((max_length, ))

  # 임베딩
  embedding_layer = Embedding(len(embeddings),
                              300,
                              weights=[embeddings],
                              input_length=max_length,
                              trainable=False,
                              embeddings_initializer=initializers.glorot_uniform(seed=main_seed))
  left_encoded = embedding_layer(left_input)
  right_encoded = embedding_layer(right_input)

  # lstm
  lstm_layer = LSTM(50,
                    kernel_initializer=initializers.glorot_uniform(seed=main_seed))
  left_output = lstm_layer(left_encoded)
  right_output = lstm_layer(right_encoded)

  # merge, flatten
  x = concatenate([left_output, right_output])
  x = Flatten()(x)

  # FC
  x = Dense(128, activation='relu',
            kernel_initializer=initializers.glorot_uniform(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(64, activation='relu',
            kernel_initializer=initializers.glorot_uniform(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(1, activation='sigmoid',
            kernel_initializer=initializers.glorot_uniform(seed=main_seed))(x)

  model = Model([left_input, right_input], [x])
  return model

# %%
lstmfc = create_LSTM_FC(max_len)

lstmfc.compile(optimizer='adam',
               loss='binary_crossentropy',
               metrics=['accuracy'])

lstmfc.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 514, 300)     211276500   input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 50)           70200       embedding_1[0][0]
#                                                                  embedding_1[1][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 100)          0           lstm_1[0][0]
#                                                                  lstm_1[1][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 100)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          12928       flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            65          dropout_1[0][0]
# ==================================================================================================
# Total params: 211,367,949
# Trainable params: 91,449
# Non-trainable params: 211,276,500
# __________________________________________________________________________________________________

# %%
tf.random.set_seed(main_seed)

early_stop, save_best, file_path = set_callbacks('LSTM_FC')

lstmfc_history = lstmfc.fit(
    [X_train['summary'], X_train['review']],
    y_train,
    batch_size=1024,
    epochs=20,
    validation_data=([X_val['summary'], X_val['review']], y_val),
    callbacks=[save_best, early_stop]);
# Out:
# Epoch 1/20
# 225/225 [==============================] - 99s 425ms/step - loss: 0.5538 - accuracy: 0.7550 - val_loss: 0.5227 - val_accuracy: 0.7703
#
# Epoch 00001: val_loss improved from inf to 0.52271, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/LSTM_FC_weight.hdf5
# Epoch 2/20
# 225/225 [==============================] - 96s 425ms/step - loss: 0.5103 - accuracy: 0.7708 - val_loss: 0.5033 - val_accuracy: 0.7713
#
# Epoch 00002: val_loss improved from 0.52271 to 0.50326, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/LSTM_FC_weight.hdf5
# Epoch 3/20
# 225/225 [==============================] - 89s 398ms/step - loss: 0.5030 - accuracy: 0.7722 - val_loss: 0.5218 - val_accuracy: 0.7736
#
# Epoch 00003: val_loss did not improve from 0.50326
# Epoch 4/20
# 225/225 [==============================] - 92s 409ms/step - loss: 0.5001 - accuracy: 0.7743 - val_loss: 0.4800 - val_accuracy: 0.7810
#
# Epoch 00004: val_loss improved from 0.50326 to 0.48003, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/LSTM_FC_weight.hdf5
# Epoch 5/20
# 225/225 [==============================] - 95s 422ms/step - loss: 0.4758 - accuracy: 0.7815 - val_loss: 0.4738 - val_accuracy: 0.7827
#
# Epoch 00005: val_loss improved from 0.48003 to 0.47384, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/LSTM_FC_weight.hdf5
# Epoch 6/20
# 225/225 [==============================] - 95s 421ms/step - loss: 0.4652 - accuracy: 0.7871 - val_loss: 0.4713 - val_accuracy: 0.7843
#
# Epoch 00006: val_loss improved from 0.47384 to 0.47126, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/LSTM_FC_weight.hdf5
# Epoch 7/20
# 225/225 [==============================] - 94s 420ms/step - loss: 0.4577 - accuracy: 0.7906 - val_loss: 0.4707 - val_accuracy: 0.7851
#
# Epoch 00007: val_loss improved from 0.47126 to 0.47071, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/LSTM_FC_weight.hdf5
# Epoch 8/20
# 225/225 [==============================] - 95s 422ms/step - loss: 0.4516 - accuracy: 0.7938 - val_loss: 0.4668 - val_accuracy: 0.7844
#
# Epoch 00008: val_loss improved from 0.47071 to 0.46679, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/LSTM_FC_weight.hdf5
# Epoch 9/20
# 225/225 [==============================] - 95s 422ms/step - loss: 0.4434 - accuracy: 0.7987 - val_loss: 0.4705 - val_accuracy: 0.7873
#
# Epoch 00009: val_loss did not improve from 0.46679
# Epoch 10/20
# 225/225 [==============================] - 94s 420ms/step - loss: 0.4346 - accuracy: 0.8034 - val_loss: 0.4709 - val_accuracy: 0.7867
#
# Epoch 00010: val_loss did not improve from 0.46679
# Epoch 11/20
# 225/225 [==============================] - 94s 420ms/step - loss: 0.4282 - accuracy: 0.8068 - val_loss: 0.4736 - val_accuracy: 0.7851
#
# Epoch 00011: val_loss did not improve from 0.46679
# Epoch 12/20
# 225/225 [==============================] - 94s 420ms/step - loss: 0.4218 - accuracy: 0.8098 - val_loss: 0.4767 - val_accuracy: 0.7850
#
# Epoch 00012: val_loss did not improve from 0.46679
# Epoch 13/20
# 225/225 [==============================] - 95s 420ms/step - loss: 0.4165 - accuracy: 0.8127 - val_loss: 0.4854 - val_accuracy: 0.7801
#
# Epoch 00013: val_loss did not improve from 0.46679
# Epoch 00013: early stopping

# %%
# validation dataset accuracy, f1_score

# %%time
lstmfc.load_weights(file_path)
y_pred = lstmfc.predict([X_val['summary'], X_val['review']])
y_pred_class = np.array([1 if value > 0.5 else 0 for value in y_pred])

print('val accuracy:', accuracy_score(y_val, y_pred_class))
print('val f1_score:', f1_score(y_val, y_pred_class))
# Out:
# val accuracy: 0.7843915689398491
# val f1_score: 0.28010813639138393
# CPU times: user 1min 4s, sys: 5 s, total: 1min 9s
# Wall time: 59.6 s

# %% [markdown]
# 새로 만든 모델의 validation dataset에 대한 정확도는 약 0.7844, f1 score는 약 0.2801로 기준 모델보다 높기 때문에 학습이 잘 된 의미있는 모델이라고 할 수 있다. 또한 MaLSTM 모델보다도 accuracy와 f1 score가 높으므로 가설이 맞음도 확인할 수 있다.

# %%
lstmfc.save(os.path.join(base_path, 'model_result', 'LSTM_FC.h5'))
show_history(lstmfc_history)

# %% [markdown]
# ### 3) 모델 발전시키기

# %% [markdown]
# #### 1. LSTM을 다른 RNN 계열 layer로 변경

# %% [markdown]
# ##### BiLSTM + FC layer

# %%
def create_BiLSTM_FC(max_length):

  # summary와 review 각각 입력 받기
  left_input= Input((max_length, ))
  right_input = Input((max_length, ))

  # 임베딩
  embedding_layer = Embedding(len(embeddings),
                              300,
                              weights=[embeddings],
                              input_length=max_length,
                              trainable=False,
                              embeddings_initializer=initializers.glorot_uniform(seed=main_seed))
  left_encoded = embedding_layer(left_input)
  right_encoded = embedding_layer(right_input)

  # Bidirectional LSTM
  lstm_layer = Bidirectional(
      LSTM(50,
           kernel_initializer=initializers.glorot_uniform(seed=main_seed)))
  left_output = lstm_layer(left_encoded)
  right_output = lstm_layer(right_encoded)

  # merge, flatten
  x = concatenate([left_output, right_output])
  x = Flatten()(x)

  # FC
  x = Dense(128, activation='relu',
            kernel_initializer=initializers.glorot_uniform(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(64, activation='relu',
            kernel_initializer=initializers.glorot_uniform(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(1, activation='sigmoid',
            kernel_initializer=initializers.glorot_uniform(seed=main_seed))(x)

  model = Model([left_input, right_input], [x])
  return model

# %%
bilstmfc = create_BiLSTM_FC(max_len)

bilstmfc.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy'])

bilstmfc.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 514, 300)     211276500   input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 100)          140400      embedding_2[0][0]
#                                                                  embedding_2[1][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 200)          0           bidirectional[0][0]
#                                                                  bidirectional[1][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 200)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          25728       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           8256        dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            65          dropout_3[0][0]
# ==================================================================================================
# Total params: 211,450,949
# Trainable params: 174,449
# Non-trainable params: 211,276,500
# __________________________________________________________________________________________________

# %%
tf.random.set_seed(main_seed)

early_stop, save_best, file_path = set_callbacks('BiLSTM_FC')

bilstmfc_history = bilstmfc.fit(
    [X_train['summary'], X_train['review']],
    y_train,
    batch_size=1024,
    epochs=20,
    validation_data=([X_val['summary'], X_val['review']], y_val),
    callbacks=[save_best, early_stop]);
# Out:
# Epoch 1/20
# 225/225 [==============================] - 145s 627ms/step - loss: 0.5525 - accuracy: 0.7573 - val_loss: 0.5312 - val_accuracy: 0.7709
#
# Epoch 00001: val_loss improved from inf to 0.53121, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/BiLSTM_FC_weight.hdf5
# Epoch 2/20
# 225/225 [==============================] - 141s 628ms/step - loss: 0.5248 - accuracy: 0.7698 - val_loss: 0.5207 - val_accuracy: 0.7657
#
# Epoch 00002: val_loss improved from 0.53121 to 0.52066, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/BiLSTM_FC_weight.hdf5
# Epoch 3/20
# 225/225 [==============================] - 142s 632ms/step - loss: 0.5187 - accuracy: 0.7714 - val_loss: 0.4840 - val_accuracy: 0.7780
#
# Epoch 00003: val_loss improved from 0.52066 to 0.48401, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/BiLSTM_FC_weight.hdf5
# Epoch 4/20
# 225/225 [==============================] - 142s 632ms/step - loss: 0.4843 - accuracy: 0.7762 - val_loss: 0.4796 - val_accuracy: 0.7734
#
# Epoch 00004: val_loss improved from 0.48401 to 0.47964, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/BiLSTM_FC_weight.hdf5
# Epoch 5/20
# 225/225 [==============================] - 142s 632ms/step - loss: 0.4752 - accuracy: 0.7787 - val_loss: 0.4740 - val_accuracy: 0.7833
#
# Epoch 00005: val_loss improved from 0.47964 to 0.47397, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/BiLSTM_FC_weight.hdf5
# Epoch 6/20
# 225/225 [==============================] - 142s 631ms/step - loss: 0.4648 - accuracy: 0.7881 - val_loss: 0.4663 - val_accuracy: 0.7850
#
# Epoch 00006: val_loss improved from 0.47397 to 0.46632, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/BiLSTM_FC_weight.hdf5
# Epoch 7/20
# 225/225 [==============================] - 142s 631ms/step - loss: 0.4556 - accuracy: 0.7916 - val_loss: 0.4649 - val_accuracy: 0.7867
#
# Epoch 00007: val_loss improved from 0.46632 to 0.46485, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/BiLSTM_FC_weight.hdf5
# Epoch 8/20
# 225/225 [==============================] - 135s 599ms/step - loss: 0.4499 - accuracy: 0.7946 - val_loss: 0.4728 - val_accuracy: 0.7793
#
# Epoch 00008: val_loss did not improve from 0.46485
# Epoch 9/20
# 225/225 [==============================] - 131s 581ms/step - loss: 0.4435 - accuracy: 0.7981 - val_loss: 0.4658 - val_accuracy: 0.7877
#
# Epoch 00009: val_loss did not improve from 0.46485
# Epoch 10/20
# 225/225 [==============================] - 132s 587ms/step - loss: 0.4334 - accuracy: 0.8037 - val_loss: 0.4665 - val_accuracy: 0.7874
#
# Epoch 00010: val_loss did not improve from 0.46485
# Epoch 11/20
# 225/225 [==============================] - 132s 585ms/step - loss: 0.4277 - accuracy: 0.8066 - val_loss: 0.4748 - val_accuracy: 0.7846
#
# Epoch 00011: val_loss did not improve from 0.46485
# Epoch 12/20
# 225/225 [==============================] - 132s 587ms/step - loss: 0.4216 - accuracy: 0.8101 - val_loss: 0.4742 - val_accuracy: 0.7876
#
# Epoch 00012: val_loss did not improve from 0.46485
# Epoch 00012: early stopping

# %%
# validation dataset accuracy, f1_score

# %%time
bilstmfc.load_weights(file_path)
y_pred = bilstmfc.predict([X_val['summary'], X_val['review']])
y_pred_class = np.array([1 if value > 0.5 else 0 for value in y_pred])

print('val accuracy:', accuracy_score(y_val, y_pred_class))
print('val f1_score:', f1_score(y_val, y_pred_class))
# Out:
# val accuracy: 0.7866899992164442
# val f1_score: 0.2972205490061096
# CPU times: user 1min 39s, sys: 7.81 s, total: 1min 47s
# Wall time: 1min 37s

# %%
bilstmfc.save(os.path.join(base_path, 'model_result', 'BiLSTM_FC.h5'))
show_history(bilstmfc_history)

# %% [markdown]
# ##### GRU + FC layer

# %%
def create_GRU_FC(max_length):

  # summary와 review 각각 입력 받기
  left_input= Input((max_length, ))
  right_input = Input((max_length, ))

  # 임베딩
  embedding_layer = Embedding(len(embeddings),
                              300,
                              weights=[embeddings],
                              input_length=max_length,
                              trainable=False,
                              embeddings_initializer=initializers.glorot_uniform(seed=main_seed))
  left_encoded = embedding_layer(left_input)
  right_encoded = embedding_layer(right_input)

  # gru
  gru_layer = GRU(50,
                  kernel_initializer=initializers.glorot_uniform(seed=main_seed),
                  recurrent_initializer=initializers.Orthogonal(seed=main_seed))
  left_output = gru_layer(left_encoded)
  right_output = gru_layer(right_encoded)

  # merge, flatten
  x = concatenate([left_output, right_output])
  x = Flatten()(x)

  # FC
  x = Dense(128, activation='relu',
            kernel_initializer=initializers.glorot_uniform(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(64, activation='relu',
            kernel_initializer=initializers.glorot_uniform(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(1, activation='sigmoid',
            kernel_initializer=initializers.glorot_uniform(seed=main_seed))(x)

  model = Model([left_input, right_input], [x])
  return model

# %%
grufc = create_GRU_FC(max_len)

grufc.compile(optimizer='adam',
               loss='binary_crossentropy',
               metrics=['accuracy'])

grufc.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 514, 300)     211276500   input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 50)           52800       embedding_3[0][0]
#                                                                  embedding_3[1][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 100)          0           gru[0][0]
#                                                                  gru[1][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 100)          0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          12928       flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 128)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           8256        dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64)           0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1)            65          dropout_5[0][0]
# ==================================================================================================
# Total params: 211,350,549
# Trainable params: 74,049
# Non-trainable params: 211,276,500
# __________________________________________________________________________________________________

# %%
tf.random.set_seed(main_seed)

early_stop, save_best, file_path = set_callbacks('GRU_FC')

gru_history = grufc.fit(
    [X_train['summary'], X_train['review']],
    y_train,
    batch_size=1024,
    epochs=20,
    validation_data=([X_val['summary'], X_val['review']], y_val),
    callbacks=[save_best, early_stop]);
# Out:
# Epoch 1/20
# 225/225 [==============================] - 92s 390ms/step - loss: 0.5573 - accuracy: 0.7536 - val_loss: 0.5196 - val_accuracy: 0.7713
#
# Epoch 00001: val_loss improved from inf to 0.51963, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/GRU_FC_weight.hdf5
# Epoch 2/20
# 225/225 [==============================] - 87s 385ms/step - loss: 0.5134 - accuracy: 0.7711 - val_loss: 0.4822 - val_accuracy: 0.7728
#
# Epoch 00002: val_loss improved from 0.51963 to 0.48215, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/GRU_FC_weight.hdf5
# Epoch 3/20
# 225/225 [==============================] - 86s 384ms/step - loss: 0.4760 - accuracy: 0.7793 - val_loss: 0.4717 - val_accuracy: 0.7817
#
# Epoch 00003: val_loss improved from 0.48215 to 0.47170, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/GRU_FC_weight.hdf5
# Epoch 4/20
# 225/225 [==============================] - 87s 386ms/step - loss: 0.4632 - accuracy: 0.7863 - val_loss: 0.4662 - val_accuracy: 0.7831
#
# Epoch 00004: val_loss improved from 0.47170 to 0.46621, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/GRU_FC_weight.hdf5
# Epoch 5/20
# 225/225 [==============================] - 87s 385ms/step - loss: 0.4540 - accuracy: 0.7916 - val_loss: 0.4631 - val_accuracy: 0.7865
#
# Epoch 00005: val_loss improved from 0.46621 to 0.46312, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/GRU_FC_weight.hdf5
# Epoch 6/20
# 225/225 [==============================] - 86s 383ms/step - loss: 0.4457 - accuracy: 0.7976 - val_loss: 0.4636 - val_accuracy: 0.7862
#
# Epoch 00006: val_loss did not improve from 0.46312
# Epoch 7/20
# 225/225 [==============================] - 86s 381ms/step - loss: 0.4382 - accuracy: 0.8010 - val_loss: 0.4603 - val_accuracy: 0.7889
#
# Epoch 00007: val_loss improved from 0.46312 to 0.46030, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/GRU_FC_weight.hdf5
# Epoch 8/20
# 225/225 [==============================] - 86s 382ms/step - loss: 0.4304 - accuracy: 0.8044 - val_loss: 0.4767 - val_accuracy: 0.7772
#
# Epoch 00008: val_loss did not improve from 0.46030
# Epoch 9/20
# 225/225 [==============================] - 86s 382ms/step - loss: 0.4218 - accuracy: 0.8089 - val_loss: 0.4627 - val_accuracy: 0.7891
#
# Epoch 00009: val_loss did not improve from 0.46030
# Epoch 10/20
# 225/225 [==============================] - 86s 381ms/step - loss: 0.4116 - accuracy: 0.8147 - val_loss: 0.4646 - val_accuracy: 0.7898
#
# Epoch 00010: val_loss did not improve from 0.46030
# Epoch 11/20
# 225/225 [==============================] - 86s 381ms/step - loss: 0.4072 - accuracy: 0.8178 - val_loss: 0.4702 - val_accuracy: 0.7909
#
# Epoch 00011: val_loss did not improve from 0.46030
# Epoch 12/20
# 225/225 [==============================] - 86s 384ms/step - loss: 0.4003 - accuracy: 0.8222 - val_loss: 0.4733 - val_accuracy: 0.7904
#
# Epoch 00012: val_loss did not improve from 0.46030
# Epoch 00012: early stopping

# %%
# validation dataset accuracy, f1_score

# %%time
grufc.load_weights(file_path)
y_pred = grufc.predict([X_val['summary'], X_val['review']])
y_pred_class = np.array([1 if value > 0.5 else 0 for value in y_pred])

print('val accuracy:', accuracy_score(y_val, y_pred_class))
print('val f1_score:', f1_score(y_val, y_pred_class))
# Out:
# val accuracy: 0.7888839553895578
# val f1_score: 0.3152901313002965
# CPU times: user 58.6 s, sys: 3.9 s, total: 1min 2s
# Wall time: 48.2 s

# %%
grufc.save(os.path.join(base_path, 'model_result', 'GRU_FC.h5'))
show_history(gru_history)

# %% [markdown]
# ##### BiGRU + FC

# %%
def create_BiGRU_FC(max_length):

  # summary와 review 각각 입력 받기
  left_input= Input((max_length, ))
  right_input = Input((max_length, ))

  # 임베딩
  embedding_layer = Embedding(len(embeddings),
                              300,
                              weights=[embeddings],
                              input_length=max_length,
                              trainable=False,
                              embeddings_initializer=initializers.glorot_uniform(seed=main_seed))
  left_encoded = embedding_layer(left_input)
  right_encoded = embedding_layer(right_input)

  # BiGRU (left_input과 right_input이 동일한 BiGRU layer를 사용함)
  bigru_layer = Bidirectional(
      GRU(50,
          kernel_initializer=initializers.glorot_uniform(seed=main_seed),
          recurrent_initializer=initializers.Orthogonal(seed=main_seed)))
  left_output = bigru_layer(left_encoded)
  right_output = bigru_layer(right_encoded)

  # merge, flatten
  x = concatenate([left_output, right_output])
  x = Flatten()(x)

  # FC
  x = Dense(128, activation='relu',
            kernel_initializer=initializers.glorot_uniform(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(64, activation='relu',
            kernel_initializer=initializers.glorot_uniform(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(1, activation='sigmoid',
            kernel_initializer=initializers.glorot_uniform(seed=main_seed))(x)

  model = Model([left_input, right_input], [x])
  return model

# %%
bigrufc = create_BiGRU_FC(max_len)

bigrufc.compile(optimizer='adam',
               loss='binary_crossentropy',
               metrics=['accuracy'])

bigrufc.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, 514)]        0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, 514)]        0
# __________________________________________________________________________________________________
# embedding_7 (Embedding)         (None, 514, 300)     211276500   input_15[0][0]
#                                                                  input_16[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 100)          105600      embedding_7[0][0]
#                                                                  embedding_7[1][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 200)          0           bidirectional_4[0][0]
#                                                                  bidirectional_4[1][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 200)          0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 128)          25728       flatten_6[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 128)          0           dense_15[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 64)           8256        dropout_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 64)           0           dense_16[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1)            65          dropout_10[0][0]
# ==================================================================================================
# Total params: 211,416,149
# Trainable params: 139,649
# Non-trainable params: 211,276,500
# __________________________________________________________________________________________________

# %%
tf.random.set_seed(42)

early_stop, save_best, file_path = set_callbacks('BiGRU_FC')

bigru_history = bigrufc.fit(
    [X_train['summary'], X_train['review']],
    y_train,
    batch_size=1024,
    epochs=20,
    validation_data=([X_val['summary'], X_val['review']], y_val),
    callbacks=[save_best, early_stop]);
# Out:
# Epoch 1/20
# 225/225 [==============================] - 136s 584ms/step - loss: 0.5558 - accuracy: 0.7577 - val_loss: 0.5223 - val_accuracy: 0.7713
#
# Epoch 00001: val_loss improved from inf to 0.52230, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/BiGRU_FC_weight.hdf5
# Epoch 2/20
# 225/225 [==============================] - 130s 580ms/step - loss: 0.5226 - accuracy: 0.7715 - val_loss: 0.5239 - val_accuracy: 0.7715
#
# Epoch 00002: val_loss did not improve from 0.52230
# Epoch 3/20
# 225/225 [==============================] - 130s 579ms/step - loss: 0.5165 - accuracy: 0.7730 - val_loss: 0.4779 - val_accuracy: 0.7806
#
# Epoch 00003: val_loss improved from 0.52230 to 0.47792, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/BiGRU_FC_weight.hdf5
# Epoch 4/20
# 225/225 [==============================] - 130s 578ms/step - loss: 0.4708 - accuracy: 0.7841 - val_loss: 0.4678 - val_accuracy: 0.7854
#
# Epoch 00004: val_loss improved from 0.47792 to 0.46777, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/BiGRU_FC_weight.hdf5
# Epoch 5/20
# 225/225 [==============================] - 130s 578ms/step - loss: 0.4576 - accuracy: 0.7911 - val_loss: 0.4635 - val_accuracy: 0.7872
#
# Epoch 00005: val_loss improved from 0.46777 to 0.46346, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/BiGRU_FC_weight.hdf5
# Epoch 6/20
# 225/225 [==============================] - 130s 578ms/step - loss: 0.4488 - accuracy: 0.7954 - val_loss: 0.4613 - val_accuracy: 0.7870
#
# Epoch 00006: val_loss improved from 0.46346 to 0.46126, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/BiGRU_FC_weight.hdf5
# Epoch 7/20
# 225/225 [==============================] - 130s 578ms/step - loss: 0.4389 - accuracy: 0.8004 - val_loss: 0.4576 - val_accuracy: 0.7909
#
# Epoch 00007: val_loss improved from 0.46126 to 0.45760, saving model to drive/MyDrive/IMDB_Spoiler_Dataset_edit/model_result/BiGRU_FC_weight.hdf5
# Epoch 8/20
# 225/225 [==============================] - 130s 580ms/step - loss: 0.4308 - accuracy: 0.8052 - val_loss: 0.4617 - val_accuracy: 0.7881
#
# Epoch 00008: val_loss did not improve from 0.45760
# Epoch 9/20
# 225/225 [==============================] - 130s 578ms/step - loss: 0.4218 - accuracy: 0.8108 - val_loss: 0.4595 - val_accuracy: 0.7927
#
# Epoch 00009: val_loss did not improve from 0.45760
# Epoch 10/20
# 225/225 [==============================] - 130s 578ms/step - loss: 0.4114 - accuracy: 0.8166 - val_loss: 0.4634 - val_accuracy: 0.7885
#
# Epoch 00010: val_loss did not improve from 0.45760
# Epoch 11/20
# 225/225 [==============================] - 130s 577ms/step - loss: 0.4079 - accuracy: 0.8189 - val_loss: 0.4655 - val_accuracy: 0.7945
#
# Epoch 00011: val_loss did not improve from 0.45760
# Epoch 12/20
# 225/225 [==============================] - 129s 575ms/step - loss: 0.3994 - accuracy: 0.8235 - val_loss: 0.4671 - val_accuracy: 0.7940
#
# Epoch 00012: val_loss did not improve from 0.45760
# Epoch 00012: early stopping

# %%
# validation dataset accuracy, f1_score

# %%time
bigrufc.load_weights(file_path)
y_pred = bigrufc.predict([X_val['summary'], X_val['review']])
y_pred_class = np.array([1 if value > 0.5 else 0 for value in y_pred])

print('val accuracy:', accuracy_score(y_val, y_pred_class))
print('val f1_score:', f1_score(y_val, y_pred_class))
# Out:
# val accuracy: 0.7909473189333194
# val f1_score: 0.34377305894892185
# CPU times: user 1min 30s, sys: 4.5 s, total: 1min 34s
# Wall time: 1min 21s

# %%
bigrufc.save(os.path.join(base_path, 'model_result', 'BiGRU_FC.h5'))
show_history(bigru_history)

# %% [markdown]
# ##### 지금까지 결과 정리
#
# |        | accuracy | f1 score |
# |:-------|:--------:|:--------:|
# | LSTM   | 0.7844   | 0.2801   |
# | GRU    | 0.7889   | 0.3153   |
# | BiLSTM | 0.7867   | 0.2972   |
# | BiGRU  | 0.7910   | 0.3438   |
#
# - 모든 새로 만든 모델의 accuracy와 f1 score가 기준 모델의 accuracy(약 0.7693), f1 score(0)보다 높았다.
#
# - 대체로 LSTM을 사용했을 때보다 GRU를 사용했을 때가 accuracy와 f1 score가 더 높았다.

# %% [markdown]
# #### 2. CNN(Conv1D) 사용
#
# - Kim, Y. (2014). Convolutional Neural Networks for Sentence Classification. *Proceedings of the 2014 Conference on Empirical Methods in Natural Language Processing (EMNLP)*, 1746–1751.
#     https://arxiv.org/abs/1408.5882
#
# - Pontes, E., & Huet, S., & Linhares, A., Torres-Moreno, J. (2018). Predicting the Semantic Textual Similarity with Siamese CNN and LSTM. *Traitement Automatique des Langues Naturelles (TALN)*, 1, 311–320.
#     https://arxiv.org/abs/1810.10641

# %% [markdown]
# ##### CNN + LSTM + FC

# %%
def create_CNN_LSTM_FC(max_length):

  # summary와 review 각각 입력 받기
  left_input= Input((max_length, ))
  right_input = Input((max_length, ))

  # 임베딩
  embedding_layer = Embedding(len(embeddings),
                              300,
                              weights=[embeddings],
                              input_length=max_length,
                              trainable=False,
                              embeddings_initializer=initializers.glorot_uniform(seed=main_seed))
  left_encoded = embedding_layer(left_input)
  right_encoded = embedding_layer(right_input)

  # 1D CNN
  cnn1d_layer = Conv1D(300, 3,
                       kernel_initializer=initializers.glorot_normal(seed=main_seed),
                       padding='same')
  left_output = cnn1d_layer(left_encoded)
  right_output = cnn1d_layer(right_encoded)

  left_output = Dropout(0.2, seed=main_seed)(left_output)
  right_output = Dropout(0.2, seed=main_seed)(right_output)

  # LSTM
  lstm_layer = LSTM(50,
                    kernel_initializer=initializers.glorot_uniform(seed=main_seed),
                    bias_initializer=initializers.Constant(value=2.5),
                    return_sequences=True)
  left_output = lstm_layer(left_output)
  right_output = lstm_layer(right_output)

  # GlobalMaxPooling1D
  max_pooling_layer = GlobalMaxPooling1D()
  left_output = max_pooling_layer(left_output)
  right_output = max_pooling_layer(right_output)

  # merge, flatten
  x = concatenate([left_output, right_output])
  x = Flatten()(x)

  # FC
  x = Dense(128, activation='relu',
            kernel_initializer=initializers.glorot_uniform(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(64, activation='relu',
            kernel_initializer=initializers.glorot_uniform(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(1, activation='sigmoid',
            kernel_initializer=initializers.glorot_uniform(seed=main_seed))(x)

  model = Model([left_input, right_input], [x])
  return model

# %%
cnnlstmfc = create_CNN_LSTM_FC(max_len)

# oprimizer = keras.optimizers.Adadelta(lr=0.01)
cnnlstmfc.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

cnnlstmfc.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 514, 300)     211276500   input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 514, 300)     270300      embedding_1[0][0]
#                                                                  embedding_1[1][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 514, 300)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 514, 300)     0           conv1d_1[1][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 514, 50)      70200       dropout_2[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 50)           0           lstm_1[0][0]
#                                                                  lstm_1[1][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 100)          0           global_max_pooling1d_1[0][0]
#                                                                  global_max_pooling1d_1[1][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 100)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          12928       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 128)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           8256        dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            65          dropout_5[0][0]
# ==================================================================================================
# Total params: 211,638,249
# Trainable params: 361,749
# Non-trainable params: 211,276,500
# __________________________________________________________________________________________________

# %%
tf.random.set_seed(main_seed)

early_stop, save_best, file_path = set_callbacks_ver2('CNN1D_LSTM_FC')

cnnlstmfc_history = cnnlstmfc.fit(
    [X_train['summary'], X_train['review']],
    y_train,
    batch_size=1024,
    epochs=20,
    validation_data=([X_val['summary'], X_val['review']], y_val),
    callbacks=[save_best, early_stop]);
# Out:
# Epoch 1/20
# 225/225 [==============================] - 110s 476ms/step - loss: 0.5538 - accuracy: 0.7586 - val_loss: 0.4860 - val_accuracy: 0.7707
#
# Epoch 00001: val_loss improved from inf to 0.48602, saving model to CNN1D_LSTM_FC_weight.hdf5
# Epoch 2/20
# 225/225 [==============================] - 106s 473ms/step - loss: 0.4846 - accuracy: 0.7745 - val_loss: 0.4724 - val_accuracy: 0.7821
#
# Epoch 00002: val_loss improved from 0.48602 to 0.47236, saving model to CNN1D_LSTM_FC_weight.hdf5
# Epoch 3/20
# 225/225 [==============================] - 106s 471ms/step - loss: 0.4661 - accuracy: 0.7851 - val_loss: 0.4638 - val_accuracy: 0.7865
#
# Epoch 00003: val_loss improved from 0.47236 to 0.46379, saving model to CNN1D_LSTM_FC_weight.hdf5
# Epoch 4/20
# 225/225 [==============================] - 106s 474ms/step - loss: 0.4579 - accuracy: 0.7894 - val_loss: 0.4617 - val_accuracy: 0.7884
#
# Epoch 00004: val_loss improved from 0.46379 to 0.46168, saving model to CNN1D_LSTM_FC_weight.hdf5
# Epoch 5/20
# 225/225 [==============================] - 106s 471ms/step - loss: 0.4513 - accuracy: 0.7915 - val_loss: 0.4588 - val_accuracy: 0.7909
#
# Epoch 00005: val_loss improved from 0.46168 to 0.45878, saving model to CNN1D_LSTM_FC_weight.hdf5
# Epoch 6/20
# 225/225 [==============================] - 106s 473ms/step - loss: 0.4430 - accuracy: 0.7973 - val_loss: 0.4619 - val_accuracy: 0.7852
#
# Epoch 00006: val_loss did not improve from 0.45878
# Epoch 7/20
# 225/225 [==============================] - 106s 470ms/step - loss: 0.4384 - accuracy: 0.8004 - val_loss: 0.4570 - val_accuracy: 0.7925
#
# Epoch 00007: val_loss improved from 0.45878 to 0.45697, saving model to CNN1D_LSTM_FC_weight.hdf5
# Epoch 8/20
# 225/225 [==============================] - 106s 470ms/step - loss: 0.4327 - accuracy: 0.8037 - val_loss: 0.4608 - val_accuracy: 0.7847
#
# Epoch 00008: val_loss did not improve from 0.45697
# Epoch 9/20
# 225/225 [==============================] - 105s 469ms/step - loss: 0.4293 - accuracy: 0.8054 - val_loss: 0.4554 - val_accuracy: 0.7922
#
# Epoch 00009: val_loss improved from 0.45697 to 0.45540, saving model to CNN1D_LSTM_FC_weight.hdf5
# Epoch 10/20
# 225/225 [==============================] - 106s 469ms/step - loss: 0.4211 - accuracy: 0.8097 - val_loss: 0.4552 - val_accuracy: 0.7932
#
# Epoch 00010: val_loss improved from 0.45540 to 0.45516, saving model to CNN1D_LSTM_FC_weight.hdf5
# Epoch 11/20
# 225/225 [==============================] - 106s 470ms/step - loss: 0.4189 - accuracy: 0.8111 - val_loss: 0.4561 - val_accuracy: 0.7921
#
# Epoch 00011: val_loss did not improve from 0.45516
# Epoch 12/20
# 225/225 [==============================] - 106s 469ms/step - loss: 0.4147 - accuracy: 0.8141 - val_loss: 0.4571 - val_accuracy: 0.7908
#
# Epoch 00012: val_loss did not improve from 0.45516
# Epoch 13/20
# 225/225 [==============================] - 106s 471ms/step - loss: 0.4117 - accuracy: 0.8140 - val_loss: 0.4613 - val_accuracy: 0.7884
#
# Epoch 00013: val_loss did not improve from 0.45516
# Epoch 14/20
# 225/225 [==============================] - 106s 471ms/step - loss: 0.4076 - accuracy: 0.8167 - val_loss: 0.4570 - val_accuracy: 0.7936
#
# Epoch 00014: val_loss did not improve from 0.45516
# Epoch 15/20
# 225/225 [==============================] - 106s 471ms/step - loss: 0.4045 - accuracy: 0.8186 - val_loss: 0.4610 - val_accuracy: 0.7909
#
# Epoch 00015: val_loss did not improve from 0.45516
# Epoch 00015: early stopping

# %%
# validation dataset accuracy, f1_score

# %%time
cnnlstmfc.load_weights(file_path)
y_pred = cnnlstmfc.predict([X_val['summary'], X_val['review']])
y_pred_class = np.array([1 if value > 0.5 else 0 for value in y_pred])

print('val accuracy:', accuracy_score(y_val, y_pred_class))
print('val f1_score:', f1_score(y_val, y_pred_class))
# Out:
# val accuracy: 0.7932457492099146
# val f1_score: 0.40788391053930734
# CPU times: user 1min 3s, sys: 2.67 s, total: 1min 6s
# Wall time: 51.7 s

# %%
cnnlstmfc.save_weights(os.path.join(base_path, 'model_result', 'CNN1D_LSTM_FC_weight.hdf5'))

# %%
cnnlstmfc.save(os.path.join(base_path, 'model_result', 'CNN1D_LSTM_FC.h5'))
show_history(cnnlstmfc_history)

# %% [markdown]
# ##### CNN + GRU + FC

# %%
def create_CNN_GRU_FC(max_length):

  # summary와 review 각각 입력 받기
  left_input= Input((max_length, ))
  right_input = Input((max_length, ))

  # 임베딩
  embedding_layer = Embedding(len(embeddings),
                              300,
                              weights=[embeddings],
                              input_length=max_length,
                              trainable=False,
                              embeddings_initializer=initializers.glorot_uniform(seed=main_seed))
  left_encoded = embedding_layer(left_input)
  right_encoded = embedding_layer(right_input)

  # 1D CNN
  cnn1d_layer = Conv1D(300, 3,
                       kernel_initializer=initializers.glorot_normal(seed=main_seed),
                       padding='same')
  left_output = cnn1d_layer(left_encoded)
  right_output = cnn1d_layer(right_encoded)

  left_output = Dropout(0.2, seed=main_seed)(left_output)
  right_output = Dropout(0.2, seed=main_seed)(right_output)

  # GRU
  gru_layer = GRU(50,
                  kernel_initializer=initializers.glorot_uniform(seed=main_seed),
                  recurrent_initializer=initializers.Orthogonal(seed=main_seed),
                  return_sequences=True)
  left_output = gru_layer(left_output)
  right_output = gru_layer(right_output)

  # GlobalMaxPooling1D
  max_pooling_layer = GlobalMaxPooling1D()
  left_output = max_pooling_layer(left_output)
  right_output = max_pooling_layer(right_output)

  # merge, flatten
  x = concatenate([left_output, right_output])
  x = Flatten()(x)

  # FC
  x = Dense(128, activation='relu',
            kernel_initializer=initializers.glorot_uniform(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(64, activation='relu',
            kernel_initializer=initializers.glorot_uniform(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(1, activation='sigmoid',
            kernel_initializer=initializers.glorot_uniform(seed=main_seed))(x)

  model = Model([left_input, right_input], [x])
  return model

# %%
cnngrufc = create_CNN_GRU_FC(max_len)

cnngrufc.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

cnngrufc.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 514, 300)     211276500   input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 514, 300)     270300      embedding[0][0]
#                                                                  embedding[1][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 514, 300)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 514, 300)     0           conv1d[1][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 514, 50)      52800       dropout[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 50)           0           gru[0][0]
#                                                                  gru[1][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 100)          0           global_max_pooling1d[0][0]
#                                                                  global_max_pooling1d[1][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 100)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          12928       flatten[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            65          dropout_3[0][0]
# ==================================================================================================
# Total params: 211,620,849
# Trainable params: 344,349
# Non-trainable params: 211,276,500
# __________________________________________________________________________________________________

# %%
tf.random.set_seed(main_seed)

early_stop, save_best, file_path = set_callbacks_ver2('CNN1D_GRU_FC')

cnngrufc_history = cnngrufc.fit(
    [X_train['summary'], X_train['review']],
    y_train,
    batch_size=1024,
    epochs=20,
    validation_data=([X_val['summary'], X_val['review']], y_val),
    callbacks=[save_best, early_stop]);
# Out:
# Epoch 1/20
# 225/225 [==============================] - 109s 452ms/step - loss: 0.5327 - accuracy: 0.7620 - val_loss: 0.4756 - val_accuracy: 0.7800
#
# Epoch 00001: val_loss improved from inf to 0.47563, saving model to CNN1D_GRU_FC_weight.hdf5
# Epoch 2/20
# 225/225 [==============================] - 100s 445ms/step - loss: 0.4725 - accuracy: 0.7804 - val_loss: 0.4651 - val_accuracy: 0.7856
#
# Epoch 00002: val_loss improved from 0.47563 to 0.46514, saving model to CNN1D_GRU_FC_weight.hdf5
# Epoch 3/20
# 225/225 [==============================] - 100s 445ms/step - loss: 0.4577 - accuracy: 0.7891 - val_loss: 0.4624 - val_accuracy: 0.7868
#
# Epoch 00003: val_loss improved from 0.46514 to 0.46235, saving model to CNN1D_GRU_FC_weight.hdf5
# Epoch 4/20
# 225/225 [==============================] - 100s 446ms/step - loss: 0.4491 - accuracy: 0.7929 - val_loss: 0.4594 - val_accuracy: 0.7894
#
# Epoch 00004: val_loss improved from 0.46235 to 0.45936, saving model to CNN1D_GRU_FC_weight.hdf5
# Epoch 5/20
# 225/225 [==============================] - 100s 445ms/step - loss: 0.4408 - accuracy: 0.7976 - val_loss: 0.4592 - val_accuracy: 0.7891
#
# Epoch 00005: val_loss improved from 0.45936 to 0.45916, saving model to CNN1D_GRU_FC_weight.hdf5
# Epoch 6/20
# 225/225 [==============================] - 101s 448ms/step - loss: 0.4306 - accuracy: 0.8058 - val_loss: 0.4611 - val_accuracy: 0.7870
#
# Epoch 00006: val_loss did not improve from 0.45916
# Epoch 7/20
# 225/225 [==============================] - 101s 447ms/step - loss: 0.4224 - accuracy: 0.8095 - val_loss: 0.4589 - val_accuracy: 0.7918
#
# Epoch 00007: val_loss improved from 0.45916 to 0.45890, saving model to CNN1D_GRU_FC_weight.hdf5
# Epoch 8/20
# 225/225 [==============================] - 100s 443ms/step - loss: 0.4171 - accuracy: 0.8127 - val_loss: 0.4615 - val_accuracy: 0.7885
#
# Epoch 00008: val_loss did not improve from 0.45890
# Epoch 9/20
# 225/225 [==============================] - 100s 443ms/step - loss: 0.4089 - accuracy: 0.8161 - val_loss: 0.4602 - val_accuracy: 0.7902
#
# Epoch 00009: val_loss did not improve from 0.45890
# Epoch 10/20
# 225/225 [==============================] - 100s 443ms/step - loss: 0.4014 - accuracy: 0.8198 - val_loss: 0.4663 - val_accuracy: 0.7894
#
# Epoch 00010: val_loss did not improve from 0.45890
# Epoch 11/20
# 225/225 [==============================] - 99s 442ms/step - loss: 0.3967 - accuracy: 0.8232 - val_loss: 0.4640 - val_accuracy: 0.7900
#
# Epoch 00011: val_loss did not improve from 0.45890
# Epoch 12/20
# 225/225 [==============================] - 100s 443ms/step - loss: 0.3895 - accuracy: 0.8264 - val_loss: 0.4684 - val_accuracy: 0.7894
#
# Epoch 00012: val_loss did not improve from 0.45890
# Epoch 00012: early stopping

# %%
# validation dataset accuracy, f1_score

# %%time
cnngrufc.load_weights(file_path)
y_pred = cnngrufc.predict([X_val['summary'], X_val['review']])
y_pred_class = np.array([1 if value > 0.5 else 0 for value in y_pred])

print('val accuracy:', accuracy_score(y_val, y_pred_class))
print('val f1_score:', f1_score(y_val, y_pred_class))
# Out:
# val accuracy: 0.791835348812913
# val f1_score: 0.3718969185909055
# CPU times: user 1min 4s, sys: 2.31 s, total: 1min 6s
# Wall time: 49.2 s

# %%
cnngrufc.save_weights(os.path.join(base_path, 'model_result', 'CNN1D_GRU_FC_weight.hdf5'))

# %%
cnngrufc.save(os.path.join(base_path, 'model_result', 'CNN1D_GRU_FC.h5'))
show_history(cnngrufc_history)

# %% [markdown]
# ##### CNN + BiLSTM + FC

# %%
def create_CNN_BiLSTM_FC(max_length):

  # summary와 review 각각 입력 받기
  left_input= Input((max_length, ))
  right_input = Input((max_length, ))

  # 임베딩
  embedding_layer = Embedding(len(embeddings),
                              300,
                              weights=[embeddings],
                              input_length=max_length,
                              trainable=False,
                              embeddings_initializer=initializers.glorot_uniform(seed=main_seed))
  left_encoded = embedding_layer(left_input)
  right_encoded = embedding_layer(right_input)

  # 1D CNN 
  cnn1d_layer = Conv1D(300, 3,
                       kernel_initializer=initializers.glorot_normal(seed=main_seed),
                       padding='same')
  left_output = cnn1d_layer(left_encoded)
  right_output = cnn1d_layer(right_encoded)

  left_output = Dropout(0.2, seed=main_seed)(left_output)
  right_output = Dropout(0.2, seed=main_seed)(right_output)

  # BiLSTM
  bilstm_layer = Bidirectional(
      LSTM(50,
           kernel_initializer=initializers.glorot_uniform(seed=main_seed),
           bias_initializer=initializers.Constant(value=2.5),
           return_sequences=True))
  left_output = bilstm_layer(left_output)
  right_output = bilstm_layer(right_output)

  # GlobalMaxPooling1D
  max_pooling_layer = GlobalMaxPooling1D()
  left_output = max_pooling_layer(left_output)
  right_output = max_pooling_layer(right_output)

  # merge, flatten
  x = concatenate([left_output, right_output])
  x = Flatten()(x)

  # FC
  x = Dense(128, activation='relu',
            kernel_initializer=initializers.glorot_normal(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(64, activation='relu',
            kernel_initializer=initializers.glorot_normal(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(1, activation='sigmoid',
            kernel_initializer=initializers.glorot_normal(seed=main_seed))(x)

  model = Model([left_input, right_input], [x])
  return model

# %%
cnnbilstmfc = create_CNN_BiLSTM_FC(max_len)

cnnbilstmfc.compile(optimizer='adam',
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

cnnbilstmfc.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 514, 300)     211276500   input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 514, 300)     270300      embedding_1[0][0]
#                                                                  embedding_1[1][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 514, 300)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 514, 300)     0           conv1d_1[1][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 514, 100)     140400      dropout_4[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 100)          0           bidirectional[0][0]
#                                                                  bidirectional[1][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 200)          0           global_max_pooling1d_1[0][0]
#                                                                  global_max_pooling1d_1[1][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 200)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          25728       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           8256        dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            65          dropout_7[0][0]
# ==================================================================================================
# Total params: 211,721,249
# Trainable params: 444,749
# Non-trainable params: 211,276,500
# __________________________________________________________________________________________________

# %%
tf.random.set_seed(main_seed)

early_stop, save_best, file_path = set_callbacks_ver2('CNN1D_BiLSTM_FC')

cnnbilstmfc_history = cnnbilstmfc.fit(
    [X_train['summary'], X_train['review']],
    y_train,
    batch_size=1024,
    epochs=20,
    validation_data=([X_val['summary'], X_val['review']], y_val),
    callbacks=[save_best, early_stop]);
# Out:
# Epoch 1/20
# 225/225 [==============================] - 147s 633ms/step - loss: 0.5478 - accuracy: 0.7649 - val_loss: 0.4870 - val_accuracy: 0.7693
#
# Epoch 00001: val_loss improved from inf to 0.48699, saving model to CNN1D_BiLSTM_FC_weight.hdf5
# Epoch 2/20
# 225/225 [==============================] - 142s 632ms/step - loss: 0.4832 - accuracy: 0.7739 - val_loss: 0.4689 - val_accuracy: 0.7836
#
# Epoch 00002: val_loss improved from 0.48699 to 0.46894, saving model to CNN1D_BiLSTM_FC_weight.hdf5
# Epoch 3/20
# 225/225 [==============================] - 146s 647ms/step - loss: 0.4642 - accuracy: 0.7861 - val_loss: 0.4640 - val_accuracy: 0.7862
#
# Epoch 00003: val_loss improved from 0.46894 to 0.46400, saving model to CNN1D_BiLSTM_FC_weight.hdf5
# Epoch 4/20
# 225/225 [==============================] - 142s 630ms/step - loss: 0.4560 - accuracy: 0.7893 - val_loss: 0.4631 - val_accuracy: 0.7879
#
# Epoch 00004: val_loss improved from 0.46400 to 0.46309, saving model to CNN1D_BiLSTM_FC_weight.hdf5
# Epoch 5/20
# 225/225 [==============================] - 148s 657ms/step - loss: 0.4496 - accuracy: 0.7921 - val_loss: 0.4577 - val_accuracy: 0.7880
#
# Epoch 00005: val_loss improved from 0.46309 to 0.45771, saving model to CNN1D_BiLSTM_FC_weight.hdf5
# Epoch 6/20
# 225/225 [==============================] - 145s 647ms/step - loss: 0.4415 - accuracy: 0.7976 - val_loss: 0.4647 - val_accuracy: 0.7797
#
# Epoch 00006: val_loss did not improve from 0.45771
# Epoch 7/20
# 225/225 [==============================] - 142s 633ms/step - loss: 0.4368 - accuracy: 0.8012 - val_loss: 0.4602 - val_accuracy: 0.7918
#
# Epoch 00007: val_loss did not improve from 0.45771
# Epoch 8/20
# 225/225 [==============================] - 143s 634ms/step - loss: 0.4306 - accuracy: 0.8050 - val_loss: 0.4792 - val_accuracy: 0.7653
#
# Epoch 00008: val_loss did not improve from 0.45771
# Epoch 9/20
# 225/225 [==============================] - 141s 629ms/step - loss: 0.4279 - accuracy: 0.8059 - val_loss: 0.4567 - val_accuracy: 0.7920
#
# Epoch 00009: val_loss improved from 0.45771 to 0.45669, saving model to CNN1D_BiLSTM_FC_weight.hdf5
# Epoch 10/20
# 225/225 [==============================] - 143s 634ms/step - loss: 0.4188 - accuracy: 0.8124 - val_loss: 0.4574 - val_accuracy: 0.7906
#
# Epoch 00010: val_loss did not improve from 0.45669
# Epoch 11/20
# 225/225 [==============================] - 141s 627ms/step - loss: 0.4160 - accuracy: 0.8118 - val_loss: 0.4566 - val_accuracy: 0.7923
#
# Epoch 00011: val_loss improved from 0.45669 to 0.45659, saving model to CNN1D_BiLSTM_FC_weight.hdf5
# Epoch 12/20
# 225/225 [==============================] - 141s 627ms/step - loss: 0.4111 - accuracy: 0.8154 - val_loss: 0.4595 - val_accuracy: 0.7898
#
# Epoch 00012: val_loss did not improve from 0.45659
# Epoch 13/20
# 225/225 [==============================] - 141s 628ms/step - loss: 0.4077 - accuracy: 0.8167 - val_loss: 0.4673 - val_accuracy: 0.7841
#
# Epoch 00013: val_loss did not improve from 0.45659
# Epoch 14/20
# 225/225 [==============================] - 145s 643ms/step - loss: 0.4020 - accuracy: 0.8204 - val_loss: 0.4623 - val_accuracy: 0.7900
#
# Epoch 00014: val_loss did not improve from 0.45659
# Epoch 15/20
# 225/225 [==============================] - 147s 652ms/step - loss: 0.3977 - accuracy: 0.8220 - val_loss: 0.4667 - val_accuracy: 0.7871
#
# Epoch 00015: val_loss did not improve from 0.45659
# Epoch 16/20
# 225/225 [==============================] - 147s 656ms/step - loss: 0.3965 - accuracy: 0.8222 - val_loss: 0.4840 - val_accuracy: 0.7929
#
# Epoch 00016: val_loss did not improve from 0.45659
# Epoch 00016: early stopping

# %%
# validation dataset accuracy, f1_score

# %%time
cnnbilstmfc.load_weights(file_path)
y_pred = cnnbilstmfc.predict([X_val['summary'], X_val['review']])
y_pred_class = np.array([1 if value > 0.5 else 0 for value in y_pred])

print('val accuracy:', accuracy_score(y_val, y_pred_class))
print('val f1_score:', f1_score(y_val, y_pred_class))
# Out:
# val accuracy: 0.7923316008044506
# val f1_score: 0.41234294161123425
# CPU times: user 1min 42s, sys: 3.89 s, total: 1min 46s
# Wall time: 1min 26s

# %%
cnnbilstmfc.save_weights(os.path.join(base_path, 'model_result', 'CNN1D_BiLSTM_FC_weight.hdf5'))

# %%
cnnbilstmfc.save(os.path.join(base_path, 'model_result', 'CNN1D_BiLSTM_FC.h5'))
show_history(cnnbilstmfc_history)

# %% [markdown]
# ##### 결과 정리
#
# |              | accuracy | f1 score |
# |:-------------|:--------:|:--------:|
# | CNN + LSTM   | 0.7932   | 0.4079   |
# | CNN + GRU    | 0.7918   | 0.3719   |
# | CNN + BiLSTM | 0.7923   | 0.4123   |
#
# - RNN layer의 종류와 상관없이 CNN을 사용했을 때의 accuracy와 f1 score가 사용하지 않았을 때보다 높았다.
# - GRU를 사용했을 때보다 LSTM을 사용했을 때가 accuracy와 f1 score 더 높았다.

# %% [markdown]
# #### 3. CNN, LSTM, BiLSTM 모두 사용하기
#
# - ['클린봇 2.0: 문맥을 이해하는 악성 댓글(단문) 탐지 AI'](https://d2.naver.com/helloworld/7753273)를 참고하여 변형함

# %% [markdown]
# ##### CNN + BiLSTM + LSTM + FC

# %%
def create_CNN_BiLSTM_LSTM_FC(max_length):

  # summary와 review 각각 입력 받기
  left_input= Input((max_length, ))
  right_input = Input((max_length, ))

  # 임베딩
  embedding_layer = Embedding(len(embeddings),
                              300,
                              weights=[embeddings],
                              input_length=max_length,
                              trainable=False,
                              embeddings_initializer=initializers.glorot_uniform(seed=main_seed))
  left_encoded = embedding_layer(left_input)
  right_encoded = embedding_layer(right_input)

  # 1D CNN (left_input과 right_input이 동일한 CNN layer를 사용함)
  cnn1d_layer = Conv1D(300, 3,
                       kernel_initializer=initializers.glorot_normal(seed=main_seed),
                       padding='same')
  left_output = cnn1d_layer(left_encoded)
  right_output = cnn1d_layer(right_encoded)

  left_output = Dropout(0.2, seed=main_seed)(left_output)
  right_output = Dropout(0.2, seed=main_seed)(right_output)

  # BiLSTM
  bilstm_layer = Bidirectional(
      LSTM(50,
           kernel_initializer=initializers.glorot_uniform(seed=main_seed),
           bias_initializer=initializers.Constant(value=2.5),
           return_sequences=True))
  left_output = bilstm_layer(left_output)
  right_output = bilstm_layer(right_output)

  left_output = Dropout(0.2, seed=main_seed)(left_output)
  right_output = Dropout(0.2, seed=main_seed)(right_output)

  # LSTM
  lstm_layer = LSTM(50,
                    kernel_initializer=initializers.glorot_uniform(seed=main_seed),
                    bias_initializer=initializers.Constant(value=2.5),
                    return_sequences=True)
  left_output = lstm_layer(left_output)
  right_output = lstm_layer(right_output)

  # GlobalMaxPooling1D
  max_pooling_layer = GlobalMaxPooling1D()
  left_output = max_pooling_layer(left_output)
  right_output = max_pooling_layer(right_output)

  # merge, flatten
  x = concatenate([left_output, right_output])
  x = Flatten()(x)

  # FC
  x = Dense(128, activation='relu',
            kernel_initializer=initializers.glorot_normal(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(64, activation='relu',
            kernel_initializer=initializers.glorot_normal(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(1, activation='sigmoid',
            kernel_initializer=initializers.glorot_normal(seed=main_seed))(x)

  model = Model([left_input, right_input], [x])
  return model

# %%
cnnbilstmlstmfc = create_CNN_BiLSTM_LSTM_FC(max_len)

cnnbilstmlstmfc.compile(optimizer='adam',
                        loss='binary_crossentropy',
                        metrics=['accuracy'])

cnnbilstmlstmfc.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 514, 300)     211276500   input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 514, 300)     270300      embedding[0][0]
#                                                                  embedding[1][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 514, 300)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 514, 300)     0           conv1d[1][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 514, 100)     140400      dropout[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 514, 100)     0           bidirectional[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 514, 100)     0           bidirectional[1][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 514, 50)      30200       dropout_2[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 50)           0           lstm_1[0][0]
#                                                                  lstm_1[1][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 100)          0           global_max_pooling1d[0][0]
#                                                                  global_max_pooling1d[1][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 100)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          12928       flatten[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 128)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            65          dropout_5[0][0]
# ==================================================================================================
# Total params: 211,738,649
# Trainable params: 462,149
# Non-trainable params: 211,276,500
# __________________________________________________________________________________________________

# %%
tf.random.set_seed(main_seed)

early_stop, save_best, file_path = set_callbacks_ver2('CNN1D_BiLSTM_LSTM_FC')

cnnbilstmlstmfc_history = cnnbilstmlstmfc.fit(
    [X_train['summary'], X_train['review']],
    y_train,
    batch_size=1024,
    epochs=20,
    validation_data=([X_val['summary'], X_val['review']], y_val),
    callbacks=[save_best, early_stop]);
# Out:
# Epoch 1/20
# 225/225 [==============================] - 190s 786ms/step - loss: 0.5471 - accuracy: 0.7667 - val_loss: 0.5076 - val_accuracy: 0.7693
#
# Epoch 00001: val_loss improved from inf to 0.50760, saving model to CNN1D_BiLSTM_LSTM_FC_weight.hdf5
# Epoch 2/20
# 225/225 [==============================] - 175s 778ms/step - loss: 0.4917 - accuracy: 0.7704 - val_loss: 0.4780 - val_accuracy: 0.7782
#
# Epoch 00002: val_loss improved from 0.50760 to 0.47798, saving model to CNN1D_BiLSTM_LSTM_FC_weight.hdf5
# Epoch 3/20
# 225/225 [==============================] - 175s 777ms/step - loss: 0.4778 - accuracy: 0.7801 - val_loss: 0.4796 - val_accuracy: 0.7781
#
# Epoch 00003: val_loss did not improve from 0.47798
# Epoch 4/20
# 225/225 [==============================] - 172s 763ms/step - loss: 0.4730 - accuracy: 0.7836 - val_loss: 0.4692 - val_accuracy: 0.7872
#
# Epoch 00004: val_loss improved from 0.47798 to 0.46916, saving model to CNN1D_BiLSTM_LSTM_FC_weight.hdf5
# Epoch 5/20
# 225/225 [==============================] - 174s 773ms/step - loss: 0.4654 - accuracy: 0.7875 - val_loss: 0.4704 - val_accuracy: 0.7833
#
# Epoch 00005: val_loss did not improve from 0.46916
# Epoch 6/20
# 225/225 [==============================] - 174s 772ms/step - loss: 0.4582 - accuracy: 0.7922 - val_loss: 0.4688 - val_accuracy: 0.7901
#
# Epoch 00006: val_loss improved from 0.46916 to 0.46882, saving model to CNN1D_BiLSTM_LSTM_FC_weight.hdf5
# Epoch 7/20
# 225/225 [==============================] - 172s 767ms/step - loss: 0.4503 - accuracy: 0.7957 - val_loss: 0.4605 - val_accuracy: 0.7937
#
# Epoch 00007: val_loss improved from 0.46882 to 0.46054, saving model to CNN1D_BiLSTM_LSTM_FC_weight.hdf5
# Epoch 8/20
# 225/225 [==============================] - 174s 774ms/step - loss: 0.4437 - accuracy: 0.8001 - val_loss: 0.4580 - val_accuracy: 0.7946
#
# Epoch 00008: val_loss improved from 0.46054 to 0.45798, saving model to CNN1D_BiLSTM_LSTM_FC_weight.hdf5
# Epoch 9/20
# 225/225 [==============================] - 175s 780ms/step - loss: 0.4383 - accuracy: 0.8035 - val_loss: 0.4526 - val_accuracy: 0.7955
#
# Epoch 00009: val_loss improved from 0.45798 to 0.45256, saving model to CNN1D_BiLSTM_LSTM_FC_weight.hdf5
# Epoch 10/20
# 225/225 [==============================] - 171s 759ms/step - loss: 0.4276 - accuracy: 0.8083 - val_loss: 0.4536 - val_accuracy: 0.7961
#
# Epoch 00010: val_loss did not improve from 0.45256
# Epoch 11/20
# 225/225 [==============================] - 174s 772ms/step - loss: 0.4256 - accuracy: 0.8098 - val_loss: 0.4585 - val_accuracy: 0.7973
#
# Epoch 00011: val_loss did not improve from 0.45256
# Epoch 12/20
# 225/225 [==============================] - 175s 777ms/step - loss: 0.4193 - accuracy: 0.8127 - val_loss: 0.4654 - val_accuracy: 0.7974
#
# Epoch 00012: val_loss did not improve from 0.45256
# Epoch 13/20
# 225/225 [==============================] - 169s 751ms/step - loss: 0.4154 - accuracy: 0.8147 - val_loss: 0.4610 - val_accuracy: 0.7987
#
# Epoch 00013: val_loss did not improve from 0.45256
# Epoch 14/20
# 225/225 [==============================] - 169s 751ms/step - loss: 0.4098 - accuracy: 0.8179 - val_loss: 0.4542 - val_accuracy: 0.7970
#
# Epoch 00014: val_loss did not improve from 0.45256
# Epoch 00014: early stopping

# %%
# validation dataset accuracy, f1_score

# %%time
cnnbilstmlstmfc.load_weights(file_path)
y_pred = cnnbilstmlstmfc.predict([X_val['summary'], X_val['review']])
y_pred_class = np.array([1 if value > 0.5 else 0 for value in y_pred])

print('val accuracy:', accuracy_score(y_val, y_pred_class))
print('val f1_score:', f1_score(y_val, y_pred_class))
# Out:
# val accuracy: 0.7955180609606394
# val f1_score: 0.3689343865871352
# CPU times: user 2min 26s, sys: 4.65 s, total: 2min 31s
# Wall time: 2min 3s

# %%
cnnbilstmlstmfc.save_weights(os.path.join(base_path, 'model_result', 'CNN1D_BiLSTM_LSTM_FC_weight.hdf5'))

# %%
cnnbilstmlstmfc.save(os.path.join(base_path, 'model_result', 'CNN1D_BiLSTM_LSTM_FC.h5'))
show_history(cnnbilstmlstmfc_history)

# %% [markdown]
# ##### CNN + LSTM + LSTM + FC

# %%
def create_CNN_LSTM_LSTM_FC(max_length):

  # summary와 review 각각 입력 받기
  left_input= Input((max_length, ))
  right_input = Input((max_length, ))

  # 임베딩
  embedding_layer = Embedding(len(embeddings),
                              300,
                              weights=[embeddings],
                              input_length=max_length,
                              trainable=False,
                              embeddings_initializer=initializers.glorot_uniform(seed=main_seed))
  left_encoded = embedding_layer(left_input)
  right_encoded = embedding_layer(right_input)

  # 1D CNN (left_input과 right_input이 동일한 CNN layer를 사용함)
  cnn1d_layer = Conv1D(300, 3,
                       kernel_initializer=initializers.glorot_normal(seed=main_seed),
                       padding='same')
  left_output = cnn1d_layer(left_encoded)
  right_output = cnn1d_layer(right_encoded)

  left_output = Dropout(0.2, seed=main_seed)(left_output)
  right_output = Dropout(0.2, seed=main_seed)(right_output)

  # LSTM1
  lstm_layer1 = LSTM(50,
                     kernel_initializer=initializers.glorot_uniform(seed=main_seed),
                     bias_initializer=initializers.Constant(value=2.5),
                     return_sequences=True)
  left_output = lstm_layer1(left_output)
  right_output = lstm_layer1(right_output)

  left_output = Dropout(0.2, seed=main_seed)(left_output)
  right_output = Dropout(0.2, seed=main_seed)(right_output)

  # LSTM2
  lstm_layer2 = LSTM(50,
                     kernel_initializer=initializers.glorot_uniform(seed=main_seed),
                     bias_initializer=initializers.Constant(value=2.5),
                     return_sequences=True)
  left_output = lstm_layer2(left_output)
  right_output = lstm_layer2(right_output)

  # GlobalMaxPooling1D
  max_pooling_layer = GlobalMaxPooling1D()
  left_output = max_pooling_layer(left_output)
  right_output = max_pooling_layer(right_output)

  # merge, flatten
  x = concatenate([left_output, right_output])
  x = Flatten()(x)

  # FC
  x = Dense(128, activation='relu',
            kernel_initializer=initializers.glorot_normal(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(64, activation='relu',
            kernel_initializer=initializers.glorot_normal(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(1, activation='sigmoid',
            kernel_initializer=initializers.glorot_normal(seed=main_seed))(x)

  model = Model([left_input, right_input], [x])
  return model

# %%
cnnlstmlstmfc = create_CNN_LSTM_LSTM_FC(max_len)

cnnlstmlstmfc.compile(optimizer='adam',
                        loss='binary_crossentropy',
                        metrics=['accuracy'])

cnnlstmlstmfc.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 514, 300)     211276500   input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 514, 300)     270300      embedding_1[0][0]
#                                                                  embedding_1[1][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 514, 300)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 514, 300)     0           conv1d_1[1][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 514, 50)      70200       dropout_6[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 514, 50)      0           lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 514, 50)      0           lstm_2[1][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 514, 50)      20200       dropout_8[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 50)           0           lstm_3[0][0]
#                                                                  lstm_3[1][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 100)          0           global_max_pooling1d_1[0][0]
#                                                                  global_max_pooling1d_1[1][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 100)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          12928       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 128)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           8256        dropout_10[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 64)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            65          dropout_11[0][0]
# ==================================================================================================
# Total params: 211,658,449
# Trainable params: 381,949
# Non-trainable params: 211,276,500
# __________________________________________________________________________________________________

# %%
tf.random.set_seed(main_seed)

early_stop, save_best, file_path = set_callbacks_ver2('CNN1D_LSTM_LSTM_FC')

cnnlstmlstmfc_history = cnnlstmlstmfc.fit(
    [X_train['summary'], X_train['review']],
    y_train,
    batch_size=1024,
    epochs=20,
    validation_data=([X_val['summary'], X_val['review']], y_val),
    callbacks=[save_best, early_stop]);
# Out:
# Epoch 1/20
# 225/225 [==============================] - 138s 592ms/step - loss: 0.5489 - accuracy: 0.7667 - val_loss: 0.4906 - val_accuracy: 0.7693
#
# Epoch 00001: val_loss improved from inf to 0.49056, saving model to CNN1D_LSTM_LSTM_FC_weight.hdf5
# Epoch 2/20
# 225/225 [==============================] - 133s 590ms/step - loss: 0.4917 - accuracy: 0.7704 - val_loss: 0.4757 - val_accuracy: 0.7821
#
# Epoch 00002: val_loss improved from 0.49056 to 0.47572, saving model to CNN1D_LSTM_LSTM_FC_weight.hdf5
# Epoch 3/20
# 225/225 [==============================] - 133s 590ms/step - loss: 0.4749 - accuracy: 0.7815 - val_loss: 0.4688 - val_accuracy: 0.7839
#
# Epoch 00003: val_loss improved from 0.47572 to 0.46876, saving model to CNN1D_LSTM_LSTM_FC_weight.hdf5
# Epoch 4/20
# 225/225 [==============================] - 133s 590ms/step - loss: 0.4676 - accuracy: 0.7848 - val_loss: 0.4660 - val_accuracy: 0.7882
#
# Epoch 00004: val_loss improved from 0.46876 to 0.46605, saving model to CNN1D_LSTM_LSTM_FC_weight.hdf5
# Epoch 5/20
# 225/225 [==============================] - 133s 590ms/step - loss: 0.4603 - accuracy: 0.7920 - val_loss: 0.4579 - val_accuracy: 0.7925
#
# Epoch 00005: val_loss improved from 0.46605 to 0.45794, saving model to CNN1D_LSTM_LSTM_FC_weight.hdf5
# Epoch 6/20
# 225/225 [==============================] - 133s 589ms/step - loss: 0.4506 - accuracy: 0.7979 - val_loss: 0.4556 - val_accuracy: 0.7960
#
# Epoch 00006: val_loss improved from 0.45794 to 0.45556, saving model to CNN1D_LSTM_LSTM_FC_weight.hdf5
# Epoch 7/20
# 225/225 [==============================] - 133s 590ms/step - loss: 0.4442 - accuracy: 0.8014 - val_loss: 0.4544 - val_accuracy: 0.7964
#
# Epoch 00007: val_loss improved from 0.45556 to 0.45443, saving model to CNN1D_LSTM_LSTM_FC_weight.hdf5
# Epoch 8/20
# 225/225 [==============================] - 133s 591ms/step - loss: 0.4388 - accuracy: 0.8054 - val_loss: 0.4541 - val_accuracy: 0.7974
#
# Epoch 00008: val_loss improved from 0.45443 to 0.45412, saving model to CNN1D_LSTM_LSTM_FC_weight.hdf5
# Epoch 9/20
# 225/225 [==============================] - 133s 591ms/step - loss: 0.4346 - accuracy: 0.8074 - val_loss: 0.4534 - val_accuracy: 0.7961
#
# Epoch 00009: val_loss improved from 0.45412 to 0.45342, saving model to CNN1D_LSTM_LSTM_FC_weight.hdf5
# Epoch 10/20
# 225/225 [==============================] - 133s 591ms/step - loss: 0.4256 - accuracy: 0.8118 - val_loss: 0.4511 - val_accuracy: 0.7969
#
# Epoch 00010: val_loss improved from 0.45342 to 0.45114, saving model to CNN1D_LSTM_LSTM_FC_weight.hdf5
# Epoch 11/20
# 225/225 [==============================] - 133s 590ms/step - loss: 0.4227 - accuracy: 0.8129 - val_loss: 0.4525 - val_accuracy: 0.7974
#
# Epoch 00011: val_loss did not improve from 0.45114
# Epoch 12/20
# 225/225 [==============================] - 132s 589ms/step - loss: 0.4191 - accuracy: 0.8160 - val_loss: 0.4564 - val_accuracy: 0.7966
#
# Epoch 00012: val_loss did not improve from 0.45114
# Epoch 13/20
# 225/225 [==============================] - 133s 591ms/step - loss: 0.4143 - accuracy: 0.8187 - val_loss: 0.4518 - val_accuracy: 0.7978
#
# Epoch 00013: val_loss did not improve from 0.45114
# Epoch 14/20
# 225/225 [==============================] - 133s 589ms/step - loss: 0.4111 - accuracy: 0.8203 - val_loss: 0.4525 - val_accuracy: 0.7960
#
# Epoch 00014: val_loss did not improve from 0.45114
# Epoch 15/20
# 225/225 [==============================] - 133s 590ms/step - loss: 0.4081 - accuracy: 0.8216 - val_loss: 0.4590 - val_accuracy: 0.7924
#
# Epoch 00015: val_loss did not improve from 0.45114
# Epoch 00015: early stopping

# %%
# validation dataset accuracy, f1_score

# %%time
cnnlstmlstmfc.load_weights(file_path)
y_pred = cnnlstmlstmfc.predict([X_val['summary'], X_val['review']])
y_pred_class = np.array([1 if value > 0.5 else 0 for value in y_pred])

print('val accuracy:', accuracy_score(y_val, y_pred_class))
print('val f1_score:', f1_score(y_val, y_pred_class))
# Out:
# val accuracy: 0.7968892835688354
# val f1_score: 0.35295585971627075
# CPU times: user 1min 50s, sys: 3.43 s, total: 1min 53s
# Wall time: 1min 29s

# %%
cnnlstmlstmfc.save_weights(os.path.join(base_path, 'model_result', 'CNN1D_LSTM_LSTM_FC_weight.hdf5'))

# %%
cnnlstmlstmfc.save(os.path.join(base_path, 'model_result', 'CNN1D_LSTM_LSTM_FC.h5'))
show_history(cnnlstmlstmfc_history)

# %% [markdown]
# ##### CNN + LSTM + BiLSTM + FC

# %%
def create_CNN_LSTM_BiLSTM_FC(max_length):

  # summary와 review 각각 입력 받기
  left_input= Input((max_length, ))
  right_input = Input((max_length, ))

  # 임베딩
  embedding_layer = Embedding(len(embeddings),
                              300,
                              weights=[embeddings],
                              input_length=max_length,
                              trainable=False,
                              embeddings_initializer=initializers.glorot_uniform(seed=main_seed))
  left_encoded = embedding_layer(left_input)
  right_encoded = embedding_layer(right_input)

  # 1D CNN (left_input과 right_input이 동일한 CNN layer를 사용함)
  cnn1d_layer = Conv1D(300, 3,
                       kernel_initializer=initializers.glorot_normal(seed=main_seed),
                       padding='same')
  left_output = cnn1d_layer(left_encoded)
  right_output = cnn1d_layer(right_encoded)

  left_output = Dropout(0.2, seed=main_seed)(left_output)
  right_output = Dropout(0.2, seed=main_seed)(right_output)

  # LSTM
  lstm_layer = LSTM(50,
                    kernel_initializer=initializers.glorot_uniform(seed=main_seed),
                    bias_initializer=initializers.Constant(value=2.5),
                    return_sequences=True)
  left_output = lstm_layer(left_output)
  right_output = lstm_layer(right_output)

  left_output = Dropout(0.2, seed=main_seed)(left_output)
  right_output = Dropout(0.2, seed=main_seed)(right_output)

  # BiLSTM
  bilstm_layer = Bidirectional(
      LSTM(50,
           kernel_initializer=initializers.glorot_uniform(seed=main_seed),
           bias_initializer=initializers.Constant(value=2.5),
           return_sequences=True))
  left_output = bilstm_layer(left_output)
  right_output = bilstm_layer(right_output)

  # GlobalMaxPooling1D
  max_pooling_layer = GlobalMaxPooling1D()
  left_output = max_pooling_layer(left_output)
  right_output = max_pooling_layer(right_output)

  # merge, flatten
  x = concatenate([left_output, right_output])
  x = Flatten()(x)

  # FC
  x = Dense(128, activation='relu',
            kernel_initializer=initializers.glorot_normal(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(64, activation='relu',
            kernel_initializer=initializers.glorot_normal(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(1, activation='sigmoid',
            kernel_initializer=initializers.glorot_normal(seed=main_seed))(x)

  model = Model([left_input, right_input], [x])
  return model

# %%
cnnlstmbilstmfc = create_CNN_LSTM_BiLSTM_FC(max_len)

cnnlstmbilstmfc.compile(optimizer='adam',
                        loss='binary_crossentropy',
                        metrics=['accuracy'])

cnnlstmbilstmfc.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 514, 300)     211276500   input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 514, 300)     270300      embedding_2[0][0]
#                                                                  embedding_2[1][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 514, 300)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 514, 300)     0           conv1d_2[1][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 514, 50)      70200       dropout_12[0][0]
#                                                                  dropout_13[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 514, 50)      0           lstm_4[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 514, 50)      0           lstm_4[1][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 514, 100)     40400       dropout_14[0][0]
#                                                                  dropout_15[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_2 (GlobalM (None, 100)          0           bidirectional_1[0][0]
#                                                                  bidirectional_1[1][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 200)          0           global_max_pooling1d_2[0][0]
#                                                                  global_max_pooling1d_2[1][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 200)          0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          25728       flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 128)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           8256        dropout_16[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 64)           0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1)            65          dropout_17[0][0]
# ==================================================================================================
# Total params: 211,691,449
# Trainable params: 414,949
# Non-trainable params: 211,276,500
# __________________________________________________________________________________________________

# %%
tf.random.set_seed(main_seed)

early_stop, save_best, file_path = set_callbacks_ver2('CNN1D_LSTM_BiLSTM_FC')

cnnlstmbilstmfc_history = cnnlstmbilstmfc.fit(
    [X_train['summary'], X_train['review']],
    y_train,
    batch_size=1024,
    epochs=20,
    validation_data=([X_val['summary'], X_val['review']], y_val),
    callbacks=[save_best, early_stop]);
# Out:
# Epoch 1/20
# 225/225 [==============================] - 169s 721ms/step - loss: 0.5541 - accuracy: 0.7648 - val_loss: 0.4898 - val_accuracy: 0.7693
#
# Epoch 00001: val_loss improved from inf to 0.48976, saving model to CNN1D_LSTM_BiLSTM_FC_weight.hdf5
# Epoch 2/20
# 225/225 [==============================] - 160s 713ms/step - loss: 0.4921 - accuracy: 0.7708 - val_loss: 0.4875 - val_accuracy: 0.7758
#
# Epoch 00002: val_loss improved from 0.48976 to 0.48752, saving model to CNN1D_LSTM_BiLSTM_FC_weight.hdf5
# Epoch 3/20
# 225/225 [==============================] - 160s 713ms/step - loss: 0.4783 - accuracy: 0.7802 - val_loss: 0.4736 - val_accuracy: 0.7841
#
# Epoch 00003: val_loss improved from 0.48752 to 0.47358, saving model to CNN1D_LSTM_BiLSTM_FC_weight.hdf5
# Epoch 4/20
# 225/225 [==============================] - 160s 713ms/step - loss: 0.4726 - accuracy: 0.7815 - val_loss: 0.4691 - val_accuracy: 0.7847
#
# Epoch 00004: val_loss improved from 0.47358 to 0.46909, saving model to CNN1D_LSTM_BiLSTM_FC_weight.hdf5
# Epoch 5/20
# 225/225 [==============================] - 160s 713ms/step - loss: 0.4657 - accuracy: 0.7860 - val_loss: 0.4651 - val_accuracy: 0.7869
#
# Epoch 00005: val_loss improved from 0.46909 to 0.46512, saving model to CNN1D_LSTM_BiLSTM_FC_weight.hdf5
# Epoch 6/20
# 225/225 [==============================] - 160s 712ms/step - loss: 0.4587 - accuracy: 0.7909 - val_loss: 0.4633 - val_accuracy: 0.7890
#
# Epoch 00006: val_loss improved from 0.46512 to 0.46334, saving model to CNN1D_LSTM_BiLSTM_FC_weight.hdf5
# Epoch 7/20
# 225/225 [==============================] - 161s 714ms/step - loss: 0.4487 - accuracy: 0.7967 - val_loss: 0.4597 - val_accuracy: 0.7904
#
# Epoch 00007: val_loss improved from 0.46334 to 0.45975, saving model to CNN1D_LSTM_BiLSTM_FC_weight.hdf5
# Epoch 8/20
# 225/225 [==============================] - 160s 712ms/step - loss: 0.4421 - accuracy: 0.8008 - val_loss: 0.4564 - val_accuracy: 0.7937
#
# Epoch 00008: val_loss improved from 0.45975 to 0.45643, saving model to CNN1D_LSTM_BiLSTM_FC_weight.hdf5
# Epoch 9/20
# 225/225 [==============================] - 160s 711ms/step - loss: 0.4365 - accuracy: 0.8056 - val_loss: 0.4552 - val_accuracy: 0.7937
#
# Epoch 00009: val_loss improved from 0.45643 to 0.45518, saving model to CNN1D_LSTM_BiLSTM_FC_weight.hdf5
# Epoch 10/20
# 225/225 [==============================] - 160s 711ms/step - loss: 0.4285 - accuracy: 0.8096 - val_loss: 0.4548 - val_accuracy: 0.7960
#
# Epoch 00010: val_loss improved from 0.45518 to 0.45477, saving model to CNN1D_LSTM_BiLSTM_FC_weight.hdf5
# Epoch 11/20
# 225/225 [==============================] - 159s 709ms/step - loss: 0.4234 - accuracy: 0.8132 - val_loss: 0.4570 - val_accuracy: 0.7957
#
# Epoch 00011: val_loss did not improve from 0.45477
# Epoch 12/20
# 225/225 [==============================] - 160s 713ms/step - loss: 0.4177 - accuracy: 0.8164 - val_loss: 0.4544 - val_accuracy: 0.7969
#
# Epoch 00012: val_loss improved from 0.45477 to 0.45441, saving model to CNN1D_LSTM_BiLSTM_FC_weight.hdf5
# Epoch 13/20
# 225/225 [==============================] - 160s 714ms/step - loss: 0.4143 - accuracy: 0.8172 - val_loss: 0.4532 - val_accuracy: 0.7967
#
# Epoch 00013: val_loss improved from 0.45441 to 0.45322, saving model to CNN1D_LSTM_BiLSTM_FC_weight.hdf5
# Epoch 14/20
# 225/225 [==============================] - 160s 712ms/step - loss: 0.4104 - accuracy: 0.8199 - val_loss: 0.4533 - val_accuracy: 0.7955
#
# Epoch 00014: val_loss did not improve from 0.45322
# Epoch 15/20
# 225/225 [==============================] - 161s 714ms/step - loss: 0.4075 - accuracy: 0.8218 - val_loss: 0.4584 - val_accuracy: 0.7955
#
# Epoch 00015: val_loss did not improve from 0.45322
# Epoch 16/20
# 225/225 [==============================] - 160s 712ms/step - loss: 0.4042 - accuracy: 0.8241 - val_loss: 0.4600 - val_accuracy: 0.7960
#
# Epoch 00016: val_loss did not improve from 0.45322
# Epoch 17/20
# 225/225 [==============================] - 160s 712ms/step - loss: 0.4003 - accuracy: 0.8262 - val_loss: 0.4615 - val_accuracy: 0.7956
#
# Epoch 00017: val_loss did not improve from 0.45322
# Epoch 18/20
# 225/225 [==============================] - 160s 713ms/step - loss: 0.3963 - accuracy: 0.8278 - val_loss: 0.4579 - val_accuracy: 0.7938
#
# Epoch 00018: val_loss did not improve from 0.45322
# Epoch 00018: early stopping

# %%
# validation dataset accuracy, f1_score

# %%time
cnnlstmbilstmfc.load_weights(file_path)
y_pred = cnnlstmbilstmfc.predict([X_val['summary'], X_val['review']])
y_pred_class = np.array([1 if value > 0.5 else 0 for value in y_pred])

print('val accuracy:', accuracy_score(y_val, y_pred_class))
print('val f1_score:', f1_score(y_val, y_pred_class))
# Out:
# val accuracy: 0.796732572413613
# val f1_score: 0.39225332864784657
# CPU times: user 2min 29s, sys: 4.78 s, total: 2min 34s
# Wall time: 2min 5s

# %%
cnnlstmbilstmfc.save_weights(os.path.join(base_path, 'model_result', 'CNN1D_LSTM_BiLSTM_FC_weight.hdf5'))

# %%
cnnlstmbilstmfc.save(os.path.join(base_path, 'model_result', 'CNN1D_LSTM_BiLSTM_FC.h5'))
show_history(cnnlstmbilstmfc_history)

# %% [markdown]
# ##### 결과 정리
#
# |                      | accuracy | f1 score |
# |:---------------------|:--------:|:--------:|
# | CNN + BiLSTM + LSTM  | 0.7955   | 0.3689   |
# | CNN + LSTM + LSTM    | 0.7969   | 0.3530   |
# | CNN + LSTM + BiLSTM  | 0.7967   | 0.3926   |
#
# - RNN 계열 layer를 하나만 사용했을 때보다 accuracy가 올라갔다. 다만, f1 score는 떨어졌다.
#
# - 가장 성능이 좋은 모델은 LSTM layer를 2개 사용하였을 때이다.

# %% [markdown]
# ### 4) CV를 사용해서 하이퍼 파라미터 튜닝
#
# 가장 accuracy가 높았던 CNN + LSTM + LSTM + FC에 대해서 진행함

# %%
from sklearn.model_selection import StratifiedKFold

# %%
batch_size = 1024
epochs = 8

# %%
def create_model_with_cv(max_length,
                         filter_size=3,
                         lstm1_node=50,
                         lstm2_node=50,
                         dropout_rate1=0.2,
                         dropout_rate2=0.2,
                         dense1_node=128,
                         dense2_node=64):
  
  # summary와 review 각각 입력 받기
  left_input= Input((max_length, ))
  right_input = Input((max_length, ))

  # 임베딩
  embedding_layer = Embedding(len(embeddings),
                              300,
                              weights=[embeddings],
                              input_length=max_length,
                              trainable=False,
                              embeddings_initializer=initializers.glorot_uniform(seed=main_seed))
  left_encoded = embedding_layer(left_input)
  right_encoded = embedding_layer(right_input)

  # 1D CNN 
  cnn1d_layer = Conv1D(300, filter_size,
                       kernel_initializer=initializers.glorot_normal(seed=main_seed),
                       padding='same')
  left_output = cnn1d_layer(left_encoded)
  right_output = cnn1d_layer(right_encoded)

  left_output = Dropout(dropout_rate1, seed=main_seed)(left_output)
  right_output = Dropout(dropout_rate1, seed=main_seed)(right_output)

  # LSTM1
  lstm_layer1 = LSTM(lstm1_node,
                     kernel_initializer=initializers.glorot_uniform(seed=main_seed),
                     bias_initializer=initializers.Constant(value=2.5),
                     return_sequences=True)
  left_output = lstm_layer1(left_output)
  right_output = lstm_layer1(right_output)

  left_output = Dropout(dropout_rate1, seed=main_seed)(left_output)
  right_output = Dropout(dropout_rate1, seed=main_seed)(right_output)

  # LSTM2
  lstm_layer2 = LSTM(lstm2_node,
                     kernel_initializer=initializers.glorot_uniform(seed=main_seed),
                     bias_initializer=initializers.Constant(value=2.5),
                     return_sequences=True)
  left_output = lstm_layer2(left_output)
  right_output = lstm_layer2(right_output)

  # GlobalMaxPooling1D
  max_pooling_layer = GlobalMaxPooling1D()
  left_output = max_pooling_layer(left_output)
  right_output = max_pooling_layer(right_output)

  # merge, flatten
  x = concatenate([left_output, right_output])
  x = Flatten()(x)

  # FC
  x = Dense(dense1_node, activation='relu',
            kernel_initializer=initializers.glorot_normal(seed=main_seed))(x)
  x = Dropout(dropout_rate2, seed=main_seed)(x)
  x = Dense(dense2_node, activation='relu',
            kernel_initializer=initializers.glorot_normal(seed=main_seed))(x)
  x = Dropout(dropout_rate2, seed=main_seed)(x)
  x = Dense(1, activation='sigmoid',
            kernel_initializer=initializers.glorot_normal(seed=main_seed))(x)

  model = Model([left_input, right_input], [x])
  return model

# %% [markdown]
# #### 1) optimizer 학습률

# %%
# seed 고정
np.random.seed(main_seed)
random.seed(main_seed)
tf.random.set_seed(main_seed)

# hyper parameter
learning_rate = np.logspace(-4, 0, 5)

kf = StratifiedKFold(len(learning_rate), True, main_seed)
score_list = []
history_list = []

for param, idx in zip(learning_rate, kf.split(X_train['summary'], y_train)):
  print('learning_rate:', param)
  X_train_summary_cv, X_val_summary_cv = X_train['summary'][idx[0]], X_train['summary'][idx[1]]
  X_train_review_cv, X_val_review_cv = X_train['review'][idx[0]], X_train['review'][idx[1]]
  y_train_cv, y_val_cv = y_train[idx[0]], y_train[idx[1]]

  # 모델 생성 및 학습
  model = create_model_with_cv(max_length=max_len)
  
  optimizer = keras.optimizers.Adam(lr=param)
  model.compile(optimizer=optimizer,
                loss='binary_crossentropy',
                metrics=['accuracy'])

  cv_history = model.fit(
      [X_train_summary_cv, X_train_review_cv],
      y_train_cv,
      batch_size=batch_size,
      epochs=epochs,
      validation_data=([X_val_summary_cv, X_val_review_cv], y_val_cv));

  score = model.evaluate([X_val_summary_cv, X_val_review_cv], y_val_cv, verbose=2)
  score_list.append(score)
  history_list.append((param, cv_history))
# Out:
# learning_rate: 0.0001
# Epoch 1/8
# 180/180 [==============================] - 115s 586ms/step - loss: 0.5683 - accuracy: 0.7568 - val_loss: 0.5437 - val_accuracy: 0.7693
# Epoch 2/8
# 180/180 [==============================] - 104s 577ms/step - loss: 0.5459 - accuracy: 0.7696 - val_loss: 0.5534 - val_accuracy: 0.7693
# Epoch 3/8
# 180/180 [==============================] - 104s 576ms/step - loss: 0.5461 - accuracy: 0.7681 - val_loss: 0.5430 - val_accuracy: 0.7693
# Epoch 4/8
# 180/180 [==============================] - 103s 575ms/step - loss: 0.5347 - accuracy: 0.7697 - val_loss: 0.5004 - val_accuracy: 0.7693
# Epoch 5/8
# 180/180 [==============================] - 103s 575ms/step - loss: 0.4992 - accuracy: 0.7675 - val_loss: 0.4881 - val_accuracy: 0.7729
# Epoch 6/8
# 180/180 [==============================] - 104s 576ms/step - loss: 0.4856 - accuracy: 0.7723 - val_loss: 0.4834 - val_accuracy: 0.7748
# Epoch 7/8
# 180/180 [==============================] - 103s 571ms/step - loss: 0.4851 - accuracy: 0.7723 - val_loss: 0.4802 - val_accuracy: 0.7789
# Epoch 8/8
# 180/180 [==============================] - 100s 557ms/step - loss: 0.4796 - accuracy: 0.7783 - val_loss: 0.4794 - val_accuracy: 0.7782
# 1436/1436 - 51s - loss: 0.4794 - accuracy: 0.7782
# learning_rate: 0.001
# Epoch 1/8
# 180/180 [==============================] - 107s 568ms/step - loss: 0.5531 - accuracy: 0.7651 - val_loss: 0.5262 - val_accuracy: 0.7693
# Epoch 2/8
# 180/180 [==============================] - 101s 564ms/step - loss: 0.5071 - accuracy: 0.7682 - val_loss: 0.4760 - val_accuracy: 0.7777
# Epoch 3/8
# 180/180 [==============================] - 102s 565ms/step - loss: 0.4801 - accuracy: 0.7764 - val_loss: 0.4698 - val_accuracy: 0.7853
# Epoch 4/8
# 180/180 [==============================] - 102s 565ms/step - loss: 0.4717 - accuracy: 0.7831 - val_loss: 0.4635 - val_accuracy: 0.7880
# Epoch 5/8
# 180/180 [==============================] - 101s 564ms/step - loss: 0.4602 - accuracy: 0.7902 - val_loss: 0.4704 - val_accuracy: 0.7855
# Epoch 6/8
# 180/180 [==============================] - 101s 564ms/step - loss: 0.4554 - accuracy: 0.7943 - val_loss: 0.4593 - val_accuracy: 0.7954
# Epoch 7/8
# 180/180 [==============================] - 101s 564ms/step - loss: 0.4476 - accuracy: 0.7998 - val_loss: 0.4563 - val_accuracy: 0.7957
# Epoch 8/8
# 180/180 [==============================] - 101s 563ms/step - loss: 0.4382 - accuracy: 0.8044 - val_loss: 0.4540 - val_accuracy: 0.7966
# 1436/1436 - 51s - loss: 0.4540 - accuracy: 0.7966
# learning_rate: 0.01
# Epoch 1/8
# 180/180 [==============================] - 110s 586ms/step - loss: 0.5926 - accuracy: 0.7657 - val_loss: 0.5025 - val_accuracy: 0.7693
# Epoch 2/8
# 180/180 [==============================] - 104s 576ms/step - loss: 0.5025 - accuracy: 0.7677 - val_loss: 0.4828 - val_accuracy: 0.7693
# Epoch 3/8
# 180/180 [==============================] - 104s 579ms/step - loss: 0.4858 - accuracy: 0.7697 - val_loss: 0.4848 - val_accuracy: 0.7817
# Epoch 4/8
# 180/180 [==============================] - 104s 580ms/step - loss: 0.4803 - accuracy: 0.7775 - val_loss: 0.4737 - val_accuracy: 0.7820
# Epoch 5/8
# 180/180 [==============================] - 104s 578ms/step - loss: 0.4758 - accuracy: 0.7783 - val_loss: 0.4924 - val_accuracy: 0.7820
# Epoch 6/8
# 180/180 [==============================] - 105s 581ms/step - loss: 0.4754 - accuracy: 0.7810 - val_loss: 0.4699 - val_accuracy: 0.7839
# Epoch 7/8
# 180/180 [==============================] - 104s 579ms/step - loss: 0.4731 - accuracy: 0.7853 - val_loss: 0.4651 - val_accuracy: 0.7858
# Epoch 8/8
# 180/180 [==============================] - 104s 578ms/step - loss: 0.4703 - accuracy: 0.7861 - val_loss: 0.4658 - val_accuracy: 0.7889
# 1436/1436 - 51s - loss: 0.4658 - accuracy: 0.7889
# learning_rate: 0.1
# Epoch 1/8
# 180/180 [==============================] - 110s 576ms/step - loss: 1.0599 - accuracy: 0.7395 - val_loss: 0.5401 - val_accuracy: 0.7693
# Epoch 2/8
# 180/180 [==============================] - 104s 581ms/step - loss: 0.5389 - accuracy: 0.7704 - val_loss: 0.5401 - val_accuracy: 0.7693
# Epoch 3/8
# 180/180 [==============================] - 103s 575ms/step - loss: 0.5406 - accuracy: 0.7690 - val_loss: 0.5402 - val_accuracy: 0.7693
# Epoch 4/8
# 180/180 [==============================] - 103s 573ms/step - loss: 0.5400 - accuracy: 0.7695 - val_loss: 0.5401 - val_accuracy: 0.7693
# Epoch 5/8
# 180/180 [==============================] - 103s 575ms/step - loss: 0.5384 - accuracy: 0.7708 - val_loss: 0.5402 - val_accuracy: 0.7693
# Epoch 6/8
# 180/180 [==============================] - 102s 569ms/step - loss: 0.5419 - accuracy: 0.7681 - val_loss: 0.5401 - val_accuracy: 0.7693
# Epoch 7/8
# 180/180 [==============================] - 103s 570ms/step - loss: 0.5408 - accuracy: 0.7689 - val_loss: 0.5401 - val_accuracy: 0.7693
# Epoch 8/8
# 180/180 [==============================] - 103s 571ms/step - loss: 0.5407 - accuracy: 0.7689 - val_loss: 0.5401 - val_accuracy: 0.7693
# 1436/1436 - 51s - loss: 0.5401 - accuracy: 0.7693
# learning_rate: 1.0
# Epoch 1/8
# 180/180 [==============================] - 111s 589ms/step - loss: 193.7339 - accuracy: 0.7352 - val_loss: 0.5411 - val_accuracy: 0.7693
# Epoch 2/8
# 180/180 [==============================] - 103s 575ms/step - loss: 0.5414 - accuracy: 0.7690 - val_loss: 0.5406 - val_accuracy: 0.7693
# Epoch 3/8
# 180/180 [==============================] - 103s 574ms/step - loss: 0.5416 - accuracy: 0.7688 - val_loss: 0.5417 - val_accuracy: 0.7693
# Epoch 4/8
# 180/180 [==============================] - 103s 574ms/step - loss: 0.5412 - accuracy: 0.7697 - val_loss: 0.5425 - val_accuracy: 0.7693
# Epoch 5/8
# 180/180 [==============================] - 103s 573ms/step - loss: 0.5419 - accuracy: 0.7698 - val_loss: 0.5411 - val_accuracy: 0.7693
# Epoch 6/8
# 180/180 [==============================] - 107s 596ms/step - loss: 0.5408 - accuracy: 0.7697 - val_loss: 0.5474 - val_accuracy: 0.7693
# Epoch 7/8
# 180/180 [==============================] - 108s 598ms/step - loss: 0.5401 - accuracy: 0.7705 - val_loss: 0.5432 - val_accuracy: 0.7693
# Epoch 8/8
# 180/180 [==============================] - 106s 588ms/step - loss: 0.5431 - accuracy: 0.7684 - val_loss: 0.5402 - val_accuracy: 0.7693
# 1436/1436 - 59s - loss: 0.5402 - accuracy: 0.7693

# %%
score_array = np.array(score_list)
result_df = pd.DataFrame({
    'learning_rate': learning_rate,
    'val_loss': score_array[:,0],
    'val_accuracy': score_array[:,1]
})

# val_accuracy가 높은 순으로 learning_rate 출력
rs = result_df.sort_values(by=['val_accuracy'], ascending=False)
learning_rate_confirm = rs.iloc[0]['learning_rate']

print(learning_rate_confirm)
rs
# Out:
# 0.001
#    learning_rate  val_loss  val_accuracy
# 1         0.0010  0.453986      0.796578
# 2         0.0100  0.465837      0.788917
# 0         0.0001  0.479446      0.778165
# 3         0.1000  0.540147      0.769306
# 4         1.0000  0.540213      0.769306

# %% [markdown]
# #### 2) CNN filter_size

# %%
# seed 고정
np.random.seed(main_seed)
random.seed(main_seed)
tf.random.set_seed(main_seed)

# hyper parameter
filter_size = (2, 3, 5, 7)

kf = StratifiedKFold(len(filter_size), True, main_seed)
score_list = []
history_list = []

for param, idx in zip(filter_size, kf.split(X_train['summary'], y_train)):
  print('filter_size:', param)
  X_train_summary_cv, X_val_summary_cv = X_train['summary'][idx[0]], X_train['summary'][idx[1]]
  X_train_review_cv, X_val_review_cv = X_train['review'][idx[0]], X_train['review'][idx[1]]
  y_train_cv, y_val_cv = y_train[idx[0]], y_train[idx[1]]

  # 모델 생성 및 학습  
  model = create_model_with_cv(max_length=max_len,
                               filter_size=param)
  
  optimizer = keras.optimizers.Adam(lr=learning_rate_confirm)
  model.compile(optimizer=optimizer,
                loss='binary_crossentropy',
                metrics=['accuracy'])

  cv_history = model.fit(
      [X_train_summary_cv, X_train_review_cv],
      y_train_cv,
      batch_size=batch_size,
      epochs=epochs,
      validation_data=([X_val_summary_cv, X_val_review_cv], y_val_cv));

  score = model.evaluate([X_val_summary_cv, X_val_review_cv], y_val_cv, verbose=2)
  score_list.append(score)
  history_list.append((param, cv_history))
# Out:
# filter_size: 2
# Epoch 1/8
# 169/169 [==============================] - 103s 584ms/step - loss: 0.5525 - accuracy: 0.7661 - val_loss: 0.5403 - val_accuracy: 0.7693
# Epoch 2/8
# 169/169 [==============================] - 98s 581ms/step - loss: 0.5402 - accuracy: 0.7699 - val_loss: 0.5021 - val_accuracy: 0.7693
# Epoch 3/8
# 169/169 [==============================] - 105s 620ms/step - loss: 0.4937 - accuracy: 0.7681 - val_loss: 0.4813 - val_accuracy: 0.7731
# Epoch 4/8
# 169/169 [==============================] - 100s 594ms/step - loss: 0.4786 - accuracy: 0.7772 - val_loss: 0.4742 - val_accuracy: 0.7826
# Epoch 5/8
# 169/169 [==============================] - 98s 582ms/step - loss: 0.4722 - accuracy: 0.7818 - val_loss: 0.4741 - val_accuracy: 0.7825
# Epoch 6/8
# 169/169 [==============================] - 100s 595ms/step - loss: 0.4682 - accuracy: 0.7832 - val_loss: 0.4813 - val_accuracy: 0.7846
# Epoch 7/8
# 169/169 [==============================] - 97s 574ms/step - loss: 0.4592 - accuracy: 0.7900 - val_loss: 0.4620 - val_accuracy: 0.7922
# Epoch 8/8
# 169/169 [==============================] - 97s 575ms/step - loss: 0.4514 - accuracy: 0.7970 - val_loss: 0.4603 - val_accuracy: 0.7930
# 1795/1795 - 75s - loss: 0.4603 - accuracy: 0.7930
# filter_size: 3
# Epoch 1/8
# 169/169 [==============================] - 107s 599ms/step - loss: 0.5544 - accuracy: 0.7651 - val_loss: 0.5304 - val_accuracy: 0.7693
# Epoch 2/8
# 169/169 [==============================] - 101s 600ms/step - loss: 0.5045 - accuracy: 0.7708 - val_loss: 0.4780 - val_accuracy: 0.7693
# Epoch 3/8
# 169/169 [==============================] - 101s 596ms/step - loss: 0.4833 - accuracy: 0.7736 - val_loss: 0.4736 - val_accuracy: 0.7786
# Epoch 4/8
# 169/169 [==============================] - 103s 609ms/step - loss: 0.4734 - accuracy: 0.7810 - val_loss: 0.4687 - val_accuracy: 0.7820
# Epoch 5/8
# 169/169 [==============================] - 100s 595ms/step - loss: 0.4674 - accuracy: 0.7843 - val_loss: 0.4630 - val_accuracy: 0.7885
# Epoch 6/8
# 169/169 [==============================] - 101s 597ms/step - loss: 0.4605 - accuracy: 0.7879 - val_loss: 0.4629 - val_accuracy: 0.7860
# Epoch 7/8
# 169/169 [==============================] - 101s 596ms/step - loss: 0.4526 - accuracy: 0.7942 - val_loss: 0.4744 - val_accuracy: 0.7743
# Epoch 8/8
# 169/169 [==============================] - 104s 614ms/step - loss: 0.4489 - accuracy: 0.7956 - val_loss: 0.4574 - val_accuracy: 0.7926
# 1795/1795 - 101s - loss: 0.4574 - accuracy: 0.7926
# filter_size: 5
# Epoch 1/8
# 169/169 [==============================] - 115s 640ms/step - loss: 0.5558 - accuracy: 0.7653 - val_loss: 0.5289 - val_accuracy: 0.7693
# Epoch 2/8
# 169/169 [==============================] - 107s 631ms/step - loss: 0.5124 - accuracy: 0.7703 - val_loss: 0.4826 - val_accuracy: 0.7724
# Epoch 3/8
# 169/169 [==============================] - 109s 645ms/step - loss: 0.4824 - accuracy: 0.7749 - val_loss: 0.4987 - val_accuracy: 0.7762
# Epoch 4/8
# 169/169 [==============================] - 106s 629ms/step - loss: 0.4786 - accuracy: 0.7808 - val_loss: 0.4830 - val_accuracy: 0.7749
# Epoch 5/8
# 169/169 [==============================] - 106s 629ms/step - loss: 0.4721 - accuracy: 0.7840 - val_loss: 0.4685 - val_accuracy: 0.7867
# Epoch 6/8
# 169/169 [==============================] - 107s 635ms/step - loss: 0.4642 - accuracy: 0.7879 - val_loss: 0.4683 - val_accuracy: 0.7880
# Epoch 7/8
# 169/169 [==============================] - 107s 632ms/step - loss: 0.4541 - accuracy: 0.7931 - val_loss: 0.4640 - val_accuracy: 0.7854
# Epoch 8/8
# 169/169 [==============================] - 106s 630ms/step - loss: 0.4433 - accuracy: 0.7996 - val_loss: 0.4643 - val_accuracy: 0.7926
# 1795/1795 - 65s - loss: 0.4643 - accuracy: 0.7926
# filter_size: 7
# Epoch 1/8
# 169/169 [==============================] - 120s 683ms/step - loss: 0.5506 - accuracy: 0.7661 - val_loss: 0.4952 - val_accuracy: 0.7693
# Epoch 2/8
# 169/169 [==============================] - 114s 678ms/step - loss: 0.4946 - accuracy: 0.7713 - val_loss: 0.4896 - val_accuracy: 0.7784
# Epoch 3/8
# 169/169 [==============================] - 114s 677ms/step - loss: 0.4829 - accuracy: 0.7762 - val_loss: 0.4810 - val_accuracy: 0.7771
# Epoch 4/8
# 169/169 [==============================] - 114s 675ms/step - loss: 0.4759 - accuracy: 0.7808 - val_loss: 0.4713 - val_accuracy: 0.7861
# Epoch 5/8
# 169/169 [==============================] - 114s 672ms/step - loss: 0.4699 - accuracy: 0.7842 - val_loss: 0.4692 - val_accuracy: 0.7830
# Epoch 6/8
# 169/169 [==============================] - 114s 676ms/step - loss: 0.4586 - accuracy: 0.7910 - val_loss: 0.4671 - val_accuracy: 0.7874
# Epoch 7/8
# 169/169 [==============================] - 114s 676ms/step - loss: 0.4527 - accuracy: 0.7922 - val_loss: 0.4637 - val_accuracy: 0.7899
# Epoch 8/8
# 169/169 [==============================] - 114s 674ms/step - loss: 0.4460 - accuracy: 0.7969 - val_loss: 0.4713 - val_accuracy: 0.7817
# 1795/1795 - 65s - loss: 0.4713 - accuracy: 0.7817

# %%
score_array = np.array(score_list)
result_df = pd.DataFrame({
    'filter_size': filter_size,
    'val_loss': score_array[:,0],
    'val_accuracy': score_array[:,1]
})

# val_accuracy가 높은 순으로 filter_size 출력
rs = result_df.sort_values(by=['val_accuracy'], ascending=False)
filter_size_confirm = rs.iloc[0]['filter_size']

print(filter_size_confirm)
rs
# Out:
# 2.0
#    filter_size  val_loss  val_accuracy
# 0            2  0.460332      0.792965
# 1            3  0.457398      0.792600
# 2            5  0.464280      0.792582
# 3            7  0.471295      0.781682

# %%
filter_size_confirm = int(filter_size_confirm)
filter_size_confirm
# Out:
# 2

# %% [markdown]
# #### 3) LSTM 노드 수

# %%
# seed 고정
np.random.seed(main_seed)
random.seed(main_seed)
tf.random.set_seed(main_seed)

# hyper parameter
lstm_node = [(50, 50), (50, 100), (100, 50), (100, 100)]

kf = StratifiedKFold(len(lstm_node), True, main_seed)
score_list = []
history_list = []

for param, idx in zip(lstm_node, kf.split(X_train['summary'], y_train)):
  print('lstm node1:', param[0], 'lstm node 2:', param[1])
  X_train_summary_cv, X_val_summary_cv = X_train['summary'][idx[0]], X_train['summary'][idx[1]]
  X_train_review_cv, X_val_review_cv = X_train['review'][idx[0]], X_train['review'][idx[1]]
  y_train_cv, y_val_cv = y_train[idx[0]], y_train[idx[1]]

  # 모델 생성 및 학습  
  model = create_model_with_cv(max_length=max_len,
                               filter_size=filter_size_confirm,
                               lstm1_node=param[0],
                               lstm2_node=param[1])
  
  optimizer = keras.optimizers.Adam(lr=learning_rate_confirm)
  model.compile(optimizer=optimizer,
                loss='binary_crossentropy',
                metrics=['accuracy'])

  cv_history = model.fit(
      [X_train_summary_cv, X_train_review_cv],
      y_train_cv,
      batch_size=batch_size,
      epochs=epochs,
      validation_data=([X_val_summary_cv, X_val_review_cv], y_val_cv));

  score = model.evaluate([X_val_summary_cv, X_val_review_cv], y_val_cv, verbose=2)
  score_list.append(score)
  history_list.append((param, cv_history))
# Out:
# lstm node1: 50 lstm node 2: 50
# Epoch 1/8
# 169/169 [==============================] - 104s 587ms/step - loss: 0.5524 - accuracy: 0.7661 - val_loss: 0.5418 - val_accuracy: 0.7693
# Epoch 2/8
# 169/169 [==============================] - 98s 583ms/step - loss: 0.5407 - accuracy: 0.7699 - val_loss: 0.5119 - val_accuracy: 0.7693
# Epoch 3/8
# 169/169 [==============================] - 99s 585ms/step - loss: 0.4978 - accuracy: 0.7680 - val_loss: 0.4873 - val_accuracy: 0.7693
# Epoch 4/8
# 169/169 [==============================] - 99s 584ms/step - loss: 0.4811 - accuracy: 0.7735 - val_loss: 0.4747 - val_accuracy: 0.7812
# Epoch 5/8
# 169/169 [==============================] - 99s 587ms/step - loss: 0.4743 - accuracy: 0.7807 - val_loss: 0.4784 - val_accuracy: 0.7822
# Epoch 6/8
# 169/169 [==============================] - 98s 582ms/step - loss: 0.4687 - accuracy: 0.7839 - val_loss: 0.4735 - val_accuracy: 0.7831
# Epoch 7/8
# 169/169 [==============================] - 99s 585ms/step - loss: 0.4622 - accuracy: 0.7870 - val_loss: 0.4644 - val_accuracy: 0.7869
# Epoch 8/8
# 169/169 [==============================] - 98s 581ms/step - loss: 0.4559 - accuracy: 0.7912 - val_loss: 0.4657 - val_accuracy: 0.7841
# 1795/1795 - 66s - loss: 0.4657 - accuracy: 0.7841
# lstm node1: 50 lstm node 2: 100
# Epoch 1/8
# 169/169 [==============================] - 112s 636ms/step - loss: 0.5583 - accuracy: 0.7629 - val_loss: 0.5227 - val_accuracy: 0.7693
# Epoch 2/8
# 169/169 [==============================] - 105s 620ms/step - loss: 0.4993 - accuracy: 0.7710 - val_loss: 0.4737 - val_accuracy: 0.7772
# Epoch 3/8
# 169/169 [==============================] - 104s 617ms/step - loss: 0.4810 - accuracy: 0.7740 - val_loss: 0.4700 - val_accuracy: 0.7799
# Epoch 4/8
# 169/169 [==============================] - 104s 618ms/step - loss: 0.4720 - accuracy: 0.7817 - val_loss: 0.4638 - val_accuracy: 0.7861
# Epoch 5/8
# 169/169 [==============================] - 104s 616ms/step - loss: 0.4653 - accuracy: 0.7863 - val_loss: 0.4605 - val_accuracy: 0.7908
# Epoch 6/8
# 169/169 [==============================] - 104s 619ms/step - loss: 0.4572 - accuracy: 0.7918 - val_loss: 0.4568 - val_accuracy: 0.7919
# Epoch 7/8
# 169/169 [==============================] - 105s 620ms/step - loss: 0.4492 - accuracy: 0.7963 - val_loss: 0.4676 - val_accuracy: 0.7769
# Epoch 8/8
# 169/169 [==============================] - 106s 627ms/step - loss: 0.4460 - accuracy: 0.7987 - val_loss: 0.4548 - val_accuracy: 0.7971
# 1795/1795 - 70s - loss: 0.4548 - accuracy: 0.7971
# lstm node1: 100 lstm node 2: 50
# Epoch 1/8
# 169/169 [==============================] - 116s 656ms/step - loss: 0.5557 - accuracy: 0.7653 - val_loss: 0.5449 - val_accuracy: 0.7693
# Epoch 2/8
# 169/169 [==============================] - 108s 640ms/step - loss: 0.5203 - accuracy: 0.7702 - val_loss: 0.4843 - val_accuracy: 0.7701
# Epoch 3/8
# 169/169 [==============================] - 108s 638ms/step - loss: 0.4858 - accuracy: 0.7712 - val_loss: 0.4817 - val_accuracy: 0.7805
# Epoch 4/8
# 169/169 [==============================] - 108s 639ms/step - loss: 0.4767 - accuracy: 0.7815 - val_loss: 0.4740 - val_accuracy: 0.7838
# Epoch 5/8
# 169/169 [==============================] - 109s 643ms/step - loss: 0.4716 - accuracy: 0.7838 - val_loss: 0.4720 - val_accuracy: 0.7844
# Epoch 6/8
# 169/169 [==============================] - 108s 640ms/step - loss: 0.4624 - accuracy: 0.7882 - val_loss: 0.4659 - val_accuracy: 0.7874
# Epoch 7/8
# 169/169 [==============================] - 108s 639ms/step - loss: 0.4554 - accuracy: 0.7917 - val_loss: 0.4611 - val_accuracy: 0.7909
# Epoch 8/8
# 169/169 [==============================] - 108s 638ms/step - loss: 0.4493 - accuracy: 0.7951 - val_loss: 0.4667 - val_accuracy: 0.7896
# 1795/1795 - 66s - loss: 0.4667 - accuracy: 0.7896
# lstm node1: 100 lstm node 2: 100
# Epoch 1/8
# 169/169 [==============================] - 123s 702ms/step - loss: 0.5578 - accuracy: 0.7639 - val_loss: 0.5411 - val_accuracy: 0.7693
# Epoch 2/8
# 169/169 [==============================] - 117s 693ms/step - loss: 0.5158 - accuracy: 0.7709 - val_loss: 0.4857 - val_accuracy: 0.7694
# Epoch 3/8
# 169/169 [==============================] - 117s 693ms/step - loss: 0.4818 - accuracy: 0.7753 - val_loss: 0.4894 - val_accuracy: 0.7713
# Epoch 4/8
# 169/169 [==============================] - 119s 704ms/step - loss: 0.4769 - accuracy: 0.7775 - val_loss: 0.4716 - val_accuracy: 0.7848
# Epoch 5/8
# 169/169 [==============================] - 121s 718ms/step - loss: 0.4715 - accuracy: 0.7834 - val_loss: 0.4723 - val_accuracy: 0.7769
# Epoch 6/8
# 169/169 [==============================] - 118s 698ms/step - loss: 0.4622 - accuracy: 0.7892 - val_loss: 0.4625 - val_accuracy: 0.7913
# Epoch 7/8
# 169/169 [==============================] - 117s 691ms/step - loss: 0.4548 - accuracy: 0.7935 - val_loss: 0.4572 - val_accuracy: 0.7936
# Epoch 8/8
# 169/169 [==============================] - 117s 691ms/step - loss: 0.4478 - accuracy: 0.7969 - val_loss: 0.4635 - val_accuracy: 0.7852
# 1795/1795 - 72s - loss: 0.4635 - accuracy: 0.7852

# %%
score_array = np.array(score_list)
result_df = pd.DataFrame({
    'lstm_node_1_2': lstm_node,
    'val_loss': score_array[:,0],
    'val_accuracy': score_array[:,1]
})

# val_accuracy가 높은 순으로 노드 수 출력 (첫번째 LSTM layer, 두번째 LSTM layer)
rs = result_df.sort_values(by=['val_accuracy'], ascending=False)
lstm_node_confirm = rs.iloc[0]['lstm_node_1_2']

print(lstm_node_confirm)
rs
# Out:
# (50, 100)
#   lstm_node_1_2  val_loss  val_accuracy
# 1     (50, 100)  0.454790      0.797057
# 2     (100, 50)  0.466665      0.789570
# 3    (100, 100)  0.463529      0.785234
# 0      (50, 50)  0.465663      0.784068

# %% [markdown]
# #### 4) dropout 비율

# %%
# seed 고정
np.random.seed(main_seed)
random.seed(main_seed)
tf.random.set_seed(main_seed)

# hyper parameter
dropout_rate = [(0.2, 0.2), (0.2, 0.5), (0.5, 0.2), (0.5, 0.5)]

kf = StratifiedKFold(len(dropout_rate), True, main_seed)
score_list = []
history_list = []

for param, idx in zip(dropout_rate, kf.split(X_train['summary'], y_train)):
  print('dropout rate 1:', param[0], 'dropout rate 2:', param[1])
  X_train_summary_cv, X_val_summary_cv = X_train['summary'][idx[0]], X_train['summary'][idx[1]]
  X_train_review_cv, X_val_review_cv = X_train['review'][idx[0]], X_train['review'][idx[1]]
  y_train_cv, y_val_cv = y_train[idx[0]], y_train[idx[1]]

  # 모델 생성 및 학습  
  model = create_model_with_cv(max_length=max_len,
                               filter_size=filter_size_confirm,
                               lstm1_node=lstm_node_confirm[0],
                               lstm2_node=lstm_node_confirm[1],
                               dropout_rate1=param[0],
                               dropout_rate2=param[1])
  
  optimizer = keras.optimizers.Adam(lr=learning_rate_confirm)
  model.compile(optimizer=optimizer,
                loss='binary_crossentropy',
                metrics=['accuracy'])

  cv_history = model.fit(
      [X_train_summary_cv, X_train_review_cv],
      y_train_cv,
      batch_size=batch_size,
      epochs=epochs,
      validation_data=([X_val_summary_cv, X_val_review_cv], y_val_cv));

  score = model.evaluate([X_val_summary_cv, X_val_review_cv], y_val_cv, verbose=2)
  score_list.append(score)
  history_list.append((param, cv_history))
# Out:
# dropout rate 1: 0.2 dropout rate 2: 0.2
# Epoch 1/8
# 169/169 [==============================] - 114s 646ms/step - loss: 0.5598 - accuracy: 0.7624 - val_loss: 0.5394 - val_accuracy: 0.7693
# Epoch 2/8
# 169/169 [==============================] - 105s 620ms/step - loss: 0.5200 - accuracy: 0.7699 - val_loss: 0.4874 - val_accuracy: 0.7693
# Epoch 3/8
# 169/169 [==============================] - 106s 628ms/step - loss: 0.4859 - accuracy: 0.7695 - val_loss: 0.4867 - val_accuracy: 0.7751
# Epoch 4/8
# 169/169 [==============================] - 107s 631ms/step - loss: 0.4771 - accuracy: 0.7794 - val_loss: 0.4735 - val_accuracy: 0.7812
# Epoch 5/8
# 169/169 [==============================] - 105s 621ms/step - loss: 0.4717 - accuracy: 0.7813 - val_loss: 0.4692 - val_accuracy: 0.7859
# Epoch 6/8
# 169/169 [==============================] - 105s 622ms/step - loss: 0.4658 - accuracy: 0.7861 - val_loss: 0.4708 - val_accuracy: 0.7845
# Epoch 7/8
# 169/169 [==============================] - 105s 621ms/step - loss: 0.4597 - accuracy: 0.7888 - val_loss: 0.4670 - val_accuracy: 0.7878
# Epoch 8/8
# 169/169 [==============================] - 105s 621ms/step - loss: 0.4538 - accuracy: 0.7941 - val_loss: 0.4624 - val_accuracy: 0.7929
# 1795/1795 - 65s - loss: 0.4624 - accuracy: 0.7929
# dropout rate 1: 0.2 dropout rate 2: 0.5
# Epoch 1/8
# 169/169 [==============================] - 114s 639ms/step - loss: 0.5781 - accuracy: 0.7541 - val_loss: 0.5469 - val_accuracy: 0.7693
# Epoch 2/8
# 169/169 [==============================] - 104s 618ms/step - loss: 0.5438 - accuracy: 0.7708 - val_loss: 0.5014 - val_accuracy: 0.7693
# Epoch 3/8
# 169/169 [==============================] - 104s 617ms/step - loss: 0.5046 - accuracy: 0.7691 - val_loss: 0.4819 - val_accuracy: 0.7693
# Epoch 4/8
# 169/169 [==============================] - 104s 616ms/step - loss: 0.4905 - accuracy: 0.7693 - val_loss: 0.4816 - val_accuracy: 0.7693
# Epoch 5/8
# 169/169 [==============================] - 104s 615ms/step - loss: 0.4850 - accuracy: 0.7712 - val_loss: 0.4716 - val_accuracy: 0.7693
# Epoch 6/8
# 169/169 [==============================] - 104s 616ms/step - loss: 0.4803 - accuracy: 0.7733 - val_loss: 0.4695 - val_accuracy: 0.7790
# Epoch 7/8
# 169/169 [==============================] - 104s 615ms/step - loss: 0.4766 - accuracy: 0.7747 - val_loss: 0.4744 - val_accuracy: 0.7774
# Epoch 8/8
# 169/169 [==============================] - 104s 616ms/step - loss: 0.4767 - accuracy: 0.7743 - val_loss: 0.4702 - val_accuracy: 0.7855
# 1795/1795 - 65s - loss: 0.4702 - accuracy: 0.7855
# dropout rate 1: 0.5 dropout rate 2: 0.2
# Epoch 1/8
# 169/169 [==============================] - 108s 614ms/step - loss: 0.5601 - accuracy: 0.7636 - val_loss: 0.5442 - val_accuracy: 0.7693
# Epoch 2/8
# 169/169 [==============================] - 101s 597ms/step - loss: 0.5423 - accuracy: 0.7702 - val_loss: 0.5224 - val_accuracy: 0.7693
# Epoch 3/8
# 169/169 [==============================] - 101s 598ms/step - loss: 0.5011 - accuracy: 0.7702 - val_loss: 0.5008 - val_accuracy: 0.7694
# Epoch 4/8
# 169/169 [==============================] - 103s 611ms/step - loss: 0.4821 - accuracy: 0.7766 - val_loss: 0.4861 - val_accuracy: 0.7820
# Epoch 5/8
# 169/169 [==============================] - 102s 602ms/step - loss: 0.4751 - accuracy: 0.7807 - val_loss: 0.4708 - val_accuracy: 0.7855
# Epoch 6/8
# 169/169 [==============================] - 102s 603ms/step - loss: 0.4691 - accuracy: 0.7818 - val_loss: 0.4704 - val_accuracy: 0.7853
# Epoch 7/8
# 169/169 [==============================] - 102s 602ms/step - loss: 0.4650 - accuracy: 0.7860 - val_loss: 0.4696 - val_accuracy: 0.7824
# Epoch 8/8
# 169/169 [==============================] - 101s 600ms/step - loss: 0.4617 - accuracy: 0.7887 - val_loss: 0.4803 - val_accuracy: 0.7821
# 1795/1795 - 64s - loss: 0.4803 - accuracy: 0.7821
# dropout rate 1: 0.5 dropout rate 2: 0.5
# Epoch 1/8
# 169/169 [==============================] - 111s 629ms/step - loss: 0.5824 - accuracy: 0.7518 - val_loss: 0.5503 - val_accuracy: 0.7693
# Epoch 2/8
# 169/169 [==============================] - 105s 623ms/step - loss: 0.5443 - accuracy: 0.7708 - val_loss: 0.5063 - val_accuracy: 0.7693
# Epoch 3/8
# 169/169 [==============================] - 105s 622ms/step - loss: 0.5025 - accuracy: 0.7701 - val_loss: 0.4912 - val_accuracy: 0.7693
# Epoch 4/8
# 169/169 [==============================] - 106s 625ms/step - loss: 0.4909 - accuracy: 0.7679 - val_loss: 0.4848 - val_accuracy: 0.7693
# Epoch 5/8
# 169/169 [==============================] - 105s 623ms/step - loss: 0.4856 - accuracy: 0.7690 - val_loss: 0.4793 - val_accuracy: 0.7693
# Epoch 6/8
# 169/169 [==============================] - 105s 624ms/step - loss: 0.4790 - accuracy: 0.7707 - val_loss: 0.4761 - val_accuracy: 0.7693
# Epoch 7/8
# 169/169 [==============================] - 105s 620ms/step - loss: 0.4763 - accuracy: 0.7714 - val_loss: 0.4733 - val_accuracy: 0.7693
# Epoch 8/8
# 169/169 [==============================] - 106s 626ms/step - loss: 0.4728 - accuracy: 0.7756 - val_loss: 0.4772 - val_accuracy: 0.7877
# 1795/1795 - 65s - loss: 0.4772 - accuracy: 0.7877

# %%
score_array = np.array(score_list)
result_df = pd.DataFrame({
    'dropout_rate_1_2': dropout_rate,
    'val_loss': score_array[:,0],
    'val_accuracy': score_array[:,1]
})

# val_accuracy가 높은 순으로 dropout 비율 출력 (CNN과 LSTM layer 부분, FC layer 부분)
rs = result_df.sort_values(by=['val_accuracy'], ascending=False)
dropout_rate_confirm = rs.iloc[0]['dropout_rate_1_2']

print(dropout_rate_confirm)
rs
# Out:
# (0.2, 0.2)
#   dropout_rate_1_2  val_loss  val_accuracy
# 0       (0.2, 0.2)  0.462355      0.792878
# 3       (0.5, 0.5)  0.477178      0.787672
# 1       (0.2, 0.5)  0.470169      0.785495
# 2       (0.5, 0.2)  0.480251      0.782065

# %% [markdown]
# #### 5) FC 노드 수 설정

# %%
# seed 고정
np.random.seed(main_seed)
random.seed(main_seed)
tf.random.set_seed(main_seed)

# hyper parameter
dense_node = [(128, 32), (256, 32), (128, 64), (256, 64), (128, 128), (256, 128)]

kf = StratifiedKFold(len(dense_node), True, main_seed)
score_list = []
history_list = []

for param, idx in zip(dense_node, kf.split(X_train['summary'], y_train)):
  print('dense node 1:', param[0], 'dense node 2:', param[1])
  X_train_summary_cv, X_val_summary_cv = X_train['summary'][idx[0]], X_train['summary'][idx[1]]
  X_train_review_cv, X_val_review_cv = X_train['review'][idx[0]], X_train['review'][idx[1]]
  y_train_cv, y_val_cv = y_train[idx[0]], y_train[idx[1]]

  # 모델 생성 및 학습  
  model = create_model_with_cv(max_length=max_len,
                               filter_size=filter_size_confirm,
                               lstm1_node=lstm_node_confirm[0],
                               lstm2_node=lstm_node_confirm[1],
                               dropout_rate1=dropout_rate_confirm[0],
                               dropout_rate2=dropout_rate_confirm[1],
                               dense1_node=param[0],
                               dense2_node=param[1])
  
  optimizer = keras.optimizers.Adam(lr=learning_rate_confirm)
  model.compile(optimizer=optimizer,
                loss='binary_crossentropy',
                metrics=['accuracy'])

  cv_history = model.fit(
      [X_train_summary_cv, X_train_review_cv],
      y_train_cv,
      batch_size=batch_size,
      epochs=epochs,
      validation_data=([X_val_summary_cv, X_val_review_cv], y_val_cv));

  score = model.evaluate([X_val_summary_cv, X_val_review_cv], y_val_cv, verbose=2)
  score_list.append(score)
  history_list.append((param, cv_history))
# Out:
# dense node 1: 128 dense node 2: 32
# Epoch 1/8
# 187/187 [==============================] - 112s 576ms/step - loss: 0.5739 - accuracy: 0.7550 - val_loss: 0.5436 - val_accuracy: 0.7693
# Epoch 2/8
# 187/187 [==============================] - 107s 572ms/step - loss: 0.5419 - accuracy: 0.7712 - val_loss: 0.5344 - val_accuracy: 0.7693
# Epoch 3/8
# 187/187 [==============================] - 107s 572ms/step - loss: 0.5140 - accuracy: 0.7687 - val_loss: 0.4790 - val_accuracy: 0.7775
# Epoch 4/8
# 187/187 [==============================] - 107s 571ms/step - loss: 0.4806 - accuracy: 0.7773 - val_loss: 0.4833 - val_accuracy: 0.7810
# Epoch 5/8
# 187/187 [==============================] - 107s 572ms/step - loss: 0.4716 - accuracy: 0.7835 - val_loss: 0.4686 - val_accuracy: 0.7837
# Epoch 6/8
# 187/187 [==============================] - 107s 571ms/step - loss: 0.4654 - accuracy: 0.7859 - val_loss: 0.4658 - val_accuracy: 0.7856
# Epoch 7/8
# 187/187 [==============================] - 107s 573ms/step - loss: 0.4583 - accuracy: 0.7890 - val_loss: 0.4627 - val_accuracy: 0.7873
# Epoch 8/8
# 187/187 [==============================] - 107s 570ms/step - loss: 0.4522 - accuracy: 0.7941 - val_loss: 0.4597 - val_accuracy: 0.7889
# 1197/1197 - 43s - loss: 0.4597 - accuracy: 0.7889
# dense node 1: 256 dense node 2: 32
# Epoch 1/8
# 187/187 [==============================] - 116s 590ms/step - loss: 0.5720 - accuracy: 0.7553 - val_loss: 0.5415 - val_accuracy: 0.7693
# Epoch 2/8
# 187/187 [==============================] - 111s 591ms/step - loss: 0.5424 - accuracy: 0.7708 - val_loss: 0.4981 - val_accuracy: 0.7693
# Epoch 3/8
# 187/187 [==============================] - 111s 594ms/step - loss: 0.4999 - accuracy: 0.7696 - val_loss: 0.4852 - val_accuracy: 0.7750
# Epoch 4/8
# 187/187 [==============================] - 110s 591ms/step - loss: 0.4837 - accuracy: 0.7759 - val_loss: 0.4729 - val_accuracy: 0.7799
# Epoch 5/8
# 187/187 [==============================] - 111s 594ms/step - loss: 0.4771 - accuracy: 0.7818 - val_loss: 0.4687 - val_accuracy: 0.7836
# Epoch 6/8
# 187/187 [==============================] - 111s 595ms/step - loss: 0.4718 - accuracy: 0.7836 - val_loss: 0.4646 - val_accuracy: 0.7857
# Epoch 7/8
# 187/187 [==============================] - 111s 591ms/step - loss: 0.4637 - accuracy: 0.7888 - val_loss: 0.4604 - val_accuracy: 0.7907
# Epoch 8/8
# 187/187 [==============================] - 110s 588ms/step - loss: 0.4537 - accuracy: 0.7955 - val_loss: 0.4539 - val_accuracy: 0.7952
# 1197/1197 - 43s - loss: 0.4539 - accuracy: 0.7952
# dense node 1: 128 dense node 2: 64
# Epoch 1/8
# 187/187 [==============================] - 115s 588ms/step - loss: 0.5575 - accuracy: 0.7644 - val_loss: 0.5479 - val_accuracy: 0.7693
# Epoch 2/8
# 187/187 [==============================] - 109s 585ms/step - loss: 0.5353 - accuracy: 0.7684 - val_loss: 0.4850 - val_accuracy: 0.7693
# Epoch 3/8
# 187/187 [==============================] - 109s 585ms/step - loss: 0.4876 - accuracy: 0.7703 - val_loss: 0.4731 - val_accuracy: 0.7837
# Epoch 4/8
# 187/187 [==============================] - 109s 583ms/step - loss: 0.4722 - accuracy: 0.7814 - val_loss: 0.4713 - val_accuracy: 0.7848
# Epoch 5/8
# 187/187 [==============================] - 109s 585ms/step - loss: 0.4668 - accuracy: 0.7866 - val_loss: 0.4664 - val_accuracy: 0.7860
# Epoch 6/8
# 187/187 [==============================] - 109s 582ms/step - loss: 0.4614 - accuracy: 0.7892 - val_loss: 0.4582 - val_accuracy: 0.7931
# Epoch 7/8
# 187/187 [==============================] - 109s 584ms/step - loss: 0.4553 - accuracy: 0.7936 - val_loss: 0.4569 - val_accuracy: 0.7937
# Epoch 8/8
# 187/187 [==============================] - 109s 583ms/step - loss: 0.4475 - accuracy: 0.7981 - val_loss: 0.4522 - val_accuracy: 0.7974
# 1197/1197 - 44s - loss: 0.4522 - accuracy: 0.7974
# dense node 1: 256 dense node 2: 64
# Epoch 1/8
# 187/187 [==============================] - 114s 585ms/step - loss: 0.5716 - accuracy: 0.7544 - val_loss: 0.5420 - val_accuracy: 0.7693
# Epoch 2/8
# 187/187 [==============================] - 109s 585ms/step - loss: 0.5368 - accuracy: 0.7689 - val_loss: 0.4931 - val_accuracy: 0.7693
# Epoch 3/8
# 187/187 [==============================] - 108s 578ms/step - loss: 0.4873 - accuracy: 0.7704 - val_loss: 0.4743 - val_accuracy: 0.7802
# Epoch 4/8
# 187/187 [==============================] - 108s 579ms/step - loss: 0.4757 - accuracy: 0.7789 - val_loss: 0.4729 - val_accuracy: 0.7806
# Epoch 5/8
# 187/187 [==============================] - 108s 578ms/step - loss: 0.4691 - accuracy: 0.7822 - val_loss: 0.4651 - val_accuracy: 0.7866
# Epoch 6/8
# 187/187 [==============================] - 108s 579ms/step - loss: 0.4610 - accuracy: 0.7894 - val_loss: 0.4637 - val_accuracy: 0.7912
# Epoch 7/8
# 187/187 [==============================] - 108s 579ms/step - loss: 0.4543 - accuracy: 0.7948 - val_loss: 0.4551 - val_accuracy: 0.7959
# Epoch 8/8
# 187/187 [==============================] - 108s 578ms/step - loss: 0.4481 - accuracy: 0.7987 - val_loss: 0.4533 - val_accuracy: 0.7963
# 1197/1197 - 43s - loss: 0.4533 - accuracy: 0.7963
# dense node 1: 128 dense node 2: 128
# Epoch 1/8
# 187/187 [==============================] - 116s 592ms/step - loss: 0.5791 - accuracy: 0.7500 - val_loss: 0.5400 - val_accuracy: 0.7693
# Epoch 2/8
# 187/187 [==============================] - 108s 580ms/step - loss: 0.5195 - accuracy: 0.7697 - val_loss: 0.4787 - val_accuracy: 0.7711
# Epoch 3/8
# 187/187 [==============================] - 109s 583ms/step - loss: 0.4798 - accuracy: 0.7759 - val_loss: 0.4717 - val_accuracy: 0.7837
# Epoch 4/8
# 187/187 [==============================] - 109s 582ms/step - loss: 0.4717 - accuracy: 0.7813 - val_loss: 0.4680 - val_accuracy: 0.7872
# Epoch 5/8
# 187/187 [==============================] - 110s 589ms/step - loss: 0.4672 - accuracy: 0.7858 - val_loss: 0.4686 - val_accuracy: 0.7858
# Epoch 6/8
# 187/187 [==============================] - 109s 581ms/step - loss: 0.4641 - accuracy: 0.7864 - val_loss: 0.4614 - val_accuracy: 0.7907
# Epoch 7/8
# 187/187 [==============================] - 109s 581ms/step - loss: 0.4573 - accuracy: 0.7896 - val_loss: 0.4597 - val_accuracy: 0.7928
# Epoch 8/8
# 187/187 [==============================] - 111s 596ms/step - loss: 0.4470 - accuracy: 0.7981 - val_loss: 0.4615 - val_accuracy: 0.7933
# 1197/1197 - 44s - loss: 0.4615 - accuracy: 0.7933
# dense node 1: 256 dense node 2: 128
# Epoch 1/8
# 187/187 [==============================] - 120s 612ms/step - loss: 0.5621 - accuracy: 0.7585 - val_loss: 0.5420 - val_accuracy: 0.7693
# Epoch 2/8
# 187/187 [==============================] - 110s 588ms/step - loss: 0.5281 - accuracy: 0.7706 - val_loss: 0.4889 - val_accuracy: 0.7694
# Epoch 3/8
# 187/187 [==============================] - 113s 606ms/step - loss: 0.4851 - accuracy: 0.7741 - val_loss: 0.4830 - val_accuracy: 0.7806
# Epoch 4/8
# 187/187 [==============================] - 110s 589ms/step - loss: 0.4730 - accuracy: 0.7832 - val_loss: 0.4708 - val_accuracy: 0.7856
# Epoch 5/8
# 187/187 [==============================] - 113s 605ms/step - loss: 0.4652 - accuracy: 0.7864 - val_loss: 0.4628 - val_accuracy: 0.7913
# Epoch 6/8
# 187/187 [==============================] - 109s 585ms/step - loss: 0.4591 - accuracy: 0.7912 - val_loss: 0.4588 - val_accuracy: 0.7917
# Epoch 7/8
# 187/187 [==============================] - 110s 586ms/step - loss: 0.4524 - accuracy: 0.7969 - val_loss: 0.4549 - val_accuracy: 0.7933
# Epoch 8/8
# 187/187 [==============================] - 112s 601ms/step - loss: 0.4427 - accuracy: 0.8019 - val_loss: 0.4556 - val_accuracy: 0.7974
# 1197/1197 - 44s - loss: 0.4556 - accuracy: 0.7974

# %%
score_array = np.array(score_list)
result_df = pd.DataFrame({
    'dense_node_1_2': dense_node,
    'val_loss': score_array[:,0],
    'val_accuracy': score_array[:,1]
})

# val_accuracy가 높은 순으로 노드 수 출력 (첫번째 dense layer, 두번째 dense layer)
rs = result_df.sort_values(by=['val_accuracy'], ascending=False)
dense_node_confirm = rs.iloc[0]['dense_node_1_2']

print(dense_node_confirm)
rs
# Out:
# (128, 64)
#   dense_node_1_2  val_loss  val_accuracy
# 2      (128, 64)  0.452207      0.797425
# 5     (256, 128)  0.455577      0.797393
# 3      (256, 64)  0.453342      0.796302
# 1      (256, 32)  0.453944      0.795179
# 4     (128, 128)  0.461456      0.793266
# 0      (128, 32)  0.459718      0.788936

# %% [markdown]
# #### 6) 배치 사이즈 설정

# %%
filter_size_confirm=2
lstm_node_confirm=(50, 100)
dropout_rate_confirm=(0.2, 0.2)
dense_node_confirm=(128, 64)
learning_rate_confirm=0.001

# %%
# seed 고정
np.random.seed(main_seed)
random.seed(main_seed)
tf.random.set_seed(main_seed)

# hyper parameter
batch_param = (64, 128, 256, 512, 1024)

kf = StratifiedKFold(len(batch_param), True, main_seed)
score_list = []
history_list = []

for param, idx in zip(batch_param, kf.split(X_train['summary'], y_train)):
  print('batch size:', param)
  X_train_summary_cv, X_val_summary_cv = X_train['summary'][idx[0]], X_train['summary'][idx[1]]
  X_train_review_cv, X_val_review_cv = X_train['review'][idx[0]], X_train['review'][idx[1]]
  y_train_cv, y_val_cv = y_train[idx[0]], y_train[idx[1]]

  # 모델 생성 및 학습  
  model = create_model_with_cv(max_length=max_len,
                               filter_size=filter_size_confirm,
                               lstm1_node=lstm_node_confirm[0],
                               lstm2_node=lstm_node_confirm[1],
                               dropout_rate1=dropout_rate_confirm[0],
                               dropout_rate2=dropout_rate_confirm[1],
                               dense1_node=dense_node_confirm[0],
                               dense2_node=dense_node_confirm[1])
  
  optimizer = keras.optimizers.Adam(lr=learning_rate_confirm)
  model.compile(optimizer=optimizer,
                loss='binary_crossentropy',
                metrics=['accuracy'])

  cv_history = model.fit(
      [X_train_summary_cv, X_train_review_cv],
      y_train_cv,
      batch_size=param,
      epochs=epochs,
      validation_data=([X_val_summary_cv, X_val_review_cv], y_val_cv));

  score = model.evaluate([X_val_summary_cv, X_val_review_cv], y_val_cv, verbose=2)
  score_list.append(score)
  history_list.append((param, cv_history))
# Out:
# batch size: 64
# Epoch 1/8
# 2872/2872 [==============================] - 383s 131ms/step - loss: 0.5403 - accuracy: 0.7661 - val_loss: 0.4790 - val_accuracy: 0.7715
# Epoch 2/8
# 2872/2872 [==============================] - 376s 131ms/step - loss: 0.4815 - accuracy: 0.7754 - val_loss: 0.4703 - val_accuracy: 0.7827
# Epoch 3/8
# 2872/2872 [==============================] - 375s 131ms/step - loss: 0.4678 - accuracy: 0.7865 - val_loss: 0.4647 - val_accuracy: 0.7917
# Epoch 4/8
# 2872/2872 [==============================] - 377s 131ms/step - loss: 0.4553 - accuracy: 0.7937 - val_loss: 0.4559 - val_accuracy: 0.7939
# Epoch 5/8
# 2872/2872 [==============================] - 373s 130ms/step - loss: 0.4516 - accuracy: 0.7963 - val_loss: 0.4625 - val_accuracy: 0.7917
# Epoch 6/8
# 2872/2872 [==============================] - 373s 130ms/step - loss: 0.4457 - accuracy: 0.7997 - val_loss: 0.4558 - val_accuracy: 0.7956
# Epoch 7/8
# 2872/2872 [==============================] - 370s 129ms/step - loss: 0.4456 - accuracy: 0.7993 - val_loss: 0.4529 - val_accuracy: 0.7931
# Epoch 8/8
# 2872/2872 [==============================] - 372s 130ms/step - loss: 0.4420 - accuracy: 0.8011 - val_loss: 0.4542 - val_accuracy: 0.7957
# 1436/1436 - 56s - loss: 0.4542 - accuracy: 0.7957
# batch size: 128
# Epoch 1/8
# 1436/1436 [==============================] - 264s 180ms/step - loss: 0.5482 - accuracy: 0.7665 - val_loss: 0.4990 - val_accuracy: 0.7693
# Epoch 2/8
# 1436/1436 [==============================] - 260s 181ms/step - loss: 0.4882 - accuracy: 0.7688 - val_loss: 0.4740 - val_accuracy: 0.7753
# Epoch 3/8
# 1436/1436 [==============================] - 259s 181ms/step - loss: 0.4733 - accuracy: 0.7802 - val_loss: 0.4660 - val_accuracy: 0.7860
# Epoch 4/8
# 1436/1436 [==============================] - 253s 176ms/step - loss: 0.4660 - accuracy: 0.7846 - val_loss: 0.4662 - val_accuracy: 0.7890
# Epoch 5/8
# 1436/1436 [==============================] - 249s 174ms/step - loss: 0.4561 - accuracy: 0.7928 - val_loss: 0.4599 - val_accuracy: 0.7899
# Epoch 6/8
# 1436/1436 [==============================] - 250s 174ms/step - loss: 0.4513 - accuracy: 0.7951 - val_loss: 0.4554 - val_accuracy: 0.7923
# Epoch 7/8
# 1436/1436 [==============================] - 250s 174ms/step - loss: 0.4471 - accuracy: 0.7996 - val_loss: 0.4578 - val_accuracy: 0.7953
# Epoch 8/8
# 1436/1436 [==============================] - 249s 173ms/step - loss: 0.4412 - accuracy: 0.8021 - val_loss: 0.4540 - val_accuracy: 0.7988
# 1436/1436 - 52s - loss: 0.4540 - accuracy: 0.7988
# batch size: 256
# Epoch 1/8
# 718/718 [==============================] - 179s 241ms/step - loss: 0.5452 - accuracy: 0.7700 - val_loss: 0.4862 - val_accuracy: 0.7693
# Epoch 2/8
# 718/718 [==============================] - 173s 241ms/step - loss: 0.4917 - accuracy: 0.7685 - val_loss: 0.4735 - val_accuracy: 0.7786
# Epoch 3/8
# 718/718 [==============================] - 173s 241ms/step - loss: 0.4764 - accuracy: 0.7775 - val_loss: 0.4691 - val_accuracy: 0.7832
# Epoch 4/8
# 718/718 [==============================] - 173s 240ms/step - loss: 0.4669 - accuracy: 0.7871 - val_loss: 0.4602 - val_accuracy: 0.7905
# Epoch 5/8
# 718/718 [==============================] - 173s 240ms/step - loss: 0.4581 - accuracy: 0.7928 - val_loss: 0.4572 - val_accuracy: 0.7946
# Epoch 6/8
# 718/718 [==============================] - 173s 241ms/step - loss: 0.4508 - accuracy: 0.7980 - val_loss: 0.4529 - val_accuracy: 0.7966
# Epoch 7/8
# 718/718 [==============================] - 173s 241ms/step - loss: 0.4446 - accuracy: 0.8002 - val_loss: 0.4487 - val_accuracy: 0.7988
# Epoch 8/8
# 718/718 [==============================] - 173s 241ms/step - loss: 0.4391 - accuracy: 0.8033 - val_loss: 0.4597 - val_accuracy: 0.7958
# 1436/1436 - 53s - loss: 0.4597 - accuracy: 0.7958
# batch size: 512
# Epoch 1/8
# 359/359 [==============================] - 138s 364ms/step - loss: 0.5545 - accuracy: 0.7656 - val_loss: 0.4968 - val_accuracy: 0.7693
# Epoch 2/8
# 359/359 [==============================] - 128s 357ms/step - loss: 0.4895 - accuracy: 0.7712 - val_loss: 0.4753 - val_accuracy: 0.7809
# Epoch 3/8
# 359/359 [==============================] - 128s 357ms/step - loss: 0.4735 - accuracy: 0.7799 - val_loss: 0.4670 - val_accuracy: 0.7844
# Epoch 4/8
# 359/359 [==============================] - 130s 362ms/step - loss: 0.4619 - accuracy: 0.7895 - val_loss: 0.4613 - val_accuracy: 0.7916
# Epoch 5/8
# 359/359 [==============================] - 130s 362ms/step - loss: 0.4530 - accuracy: 0.7942 - val_loss: 0.4590 - val_accuracy: 0.7951
# Epoch 6/8
# 359/359 [==============================] - 129s 358ms/step - loss: 0.4504 - accuracy: 0.7957 - val_loss: 0.4557 - val_accuracy: 0.7959
# Epoch 7/8
# 359/359 [==============================] - 129s 361ms/step - loss: 0.4435 - accuracy: 0.8004 - val_loss: 0.4560 - val_accuracy: 0.7948
# Epoch 8/8
# 359/359 [==============================] - 128s 358ms/step - loss: 0.4400 - accuracy: 0.8017 - val_loss: 0.4534 - val_accuracy: 0.7966
# 1436/1436 - 54s - loss: 0.4534 - accuracy: 0.7966
# batch size: 1024
# Epoch 1/8
# 180/180 [==============================] - 116s 615ms/step - loss: 0.5581 - accuracy: 0.7640 - val_loss: 0.5486 - val_accuracy: 0.7693
# Epoch 2/8
# 180/180 [==============================] - 109s 604ms/step - loss: 0.5323 - accuracy: 0.7690 - val_loss: 0.4885 - val_accuracy: 0.7693
# Epoch 3/8
# 180/180 [==============================] - 109s 604ms/step - loss: 0.4877 - accuracy: 0.7702 - val_loss: 0.4807 - val_accuracy: 0.7732
# Epoch 4/8
# 180/180 [==============================] - 108s 600ms/step - loss: 0.4781 - accuracy: 0.7798 - val_loss: 0.4771 - val_accuracy: 0.7724
# Epoch 5/8
# 180/180 [==============================] - 108s 602ms/step - loss: 0.4727 - accuracy: 0.7817 - val_loss: 0.4670 - val_accuracy: 0.7875
# Epoch 6/8
# 180/180 [==============================] - 109s 605ms/step - loss: 0.4650 - accuracy: 0.7860 - val_loss: 0.4700 - val_accuracy: 0.7814
# Epoch 7/8
# 180/180 [==============================] - 108s 603ms/step - loss: 0.4570 - accuracy: 0.7916 - val_loss: 0.4578 - val_accuracy: 0.7928
# Epoch 8/8
# 180/180 [==============================] - 108s 601ms/step - loss: 0.4509 - accuracy: 0.7956 - val_loss: 0.4553 - val_accuracy: 0.7953
# 1436/1436 - 52s - loss: 0.4553 - accuracy: 0.7953

# %%
score_array = np.array(score_list)
result_df = pd.DataFrame({
    'batch_size': batch_param,
    'val_loss': score_array[:,0],
    'val_accuracy': score_array[:,1]
})

# val_accuracy가 높은 순으로 batch size 출력
rs = result_df.sort_values(by=['val_accuracy'], ascending=False)
batch_size_confirm = rs.iloc[0]['batch_size']

print(batch_size_confirm)
rs
# Out:
# 128.0
#    batch_size  val_loss  val_accuracy
# 1         128  0.453952      0.798799
# 3         512  0.453432      0.796557
# 2         256  0.459663      0.795751
# 0          64  0.454211      0.795708
# 4        1024  0.455264      0.795273

# %%
batch_size_confirm = int(batch_size_confirm)
batch_size_confirm
# Out:
# 128

# %% [markdown]
# #### 7) early stoping 이용해서 마지막으로 학습하여 최종 모델 생성

# %%
def create_Final_model(max_length):

  # summary와 review 각각 입력 받기
  left_input= Input((max_length, ))
  right_input = Input((max_length, ))

  # 임베딩
  embedding_layer = Embedding(len(embeddings),
                              300,
                              weights=[embeddings],
                              input_length=max_length,
                              trainable=False,
                              embeddings_initializer=initializers.glorot_uniform(seed=main_seed))
  left_encoded = embedding_layer(left_input)
  right_encoded = embedding_layer(right_input)

  # 1D CNN
  cnn1d_layer = Conv1D(300, 2,
                       kernel_initializer=initializers.glorot_normal(seed=main_seed),
                       padding='same')
  left_output = cnn1d_layer(left_encoded)
  right_output = cnn1d_layer(right_encoded)

  left_output = Dropout(0.2, seed=main_seed)(left_output)
  right_output = Dropout(0.2, seed=main_seed)(right_output)

  # LSTM1
  lstm_layer1 = LSTM(50,
                     kernel_initializer=initializers.glorot_uniform(seed=main_seed),
                     bias_initializer=initializers.Constant(value=2.5),
                     return_sequences=True)
  left_output = lstm_layer1(left_output)
  right_output = lstm_layer1(right_output)

  left_output = Dropout(0.2, seed=main_seed)(left_output)
  right_output = Dropout(0.2, seed=main_seed)(right_output)

  # LSTM2
  lstm_layer2 = LSTM(100,
                     kernel_initializer=initializers.glorot_uniform(seed=main_seed),
                     bias_initializer=initializers.Constant(value=2.5),
                     return_sequences=True)
  left_output = lstm_layer2(left_output)
  right_output = lstm_layer2(right_output)

  # GlobalMaxPooling1D
  max_pooling_layer = GlobalMaxPooling1D()
  left_output = max_pooling_layer(left_output)
  right_output = max_pooling_layer(right_output)

  # merge, flatten
  x = concatenate([left_output, right_output])
  x = Flatten()(x)

  # FC
  x = Dense(128, activation='relu',
            kernel_initializer=initializers.glorot_normal(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(64, activation='relu',
            kernel_initializer=initializers.glorot_normal(seed=main_seed))(x)
  x = Dropout(0.2, seed=main_seed)(x)
  x = Dense(1, activation='sigmoid',
            kernel_initializer=initializers.glorot_normal(seed=main_seed))(x)

  model = Model([left_input, right_input], [x])
  return model

# %%
final_model = create_Final_model(max_len)

optimizer = keras.optimizers.Adam(lr=0.001)
final_model.compile(optimizer=optimizer,
                    loss='binary_crossentropy',
                    metrics=['accuracy'])

# %%
final_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 514)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 514, 300)     211276500   input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 514, 300)     180300      embedding[0][0]
#                                                                  embedding[1][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 514, 300)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 514, 300)     0           conv1d[1][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 514, 50)      70200       dropout[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 514, 50)      0           lstm[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 514, 50)      0           lstm[1][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 514, 100)     60400       dropout_2[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 100)          0           lstm_1[0][0]
#                                                                  lstm_1[1][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 200)          0           global_max_pooling1d[0][0]
#                                                                  global_max_pooling1d[1][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 200)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          25728       flatten[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 128)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            65          dropout_5[0][0]
# ==================================================================================================
# Total params: 211,621,449
# Trainable params: 344,949
# Non-trainable params: 211,276,500
# __________________________________________________________________________________________________

# %%
tf.random.set_seed(main_seed)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0,
    patience=10,
    verbose=2)
  
file_path = 'Final_Model_weight.hdf5'
save_best = tf.keras.callbacks.ModelCheckpoint(
  filepath=file_path,
  monitor='val_loss',
  verbose=2,
  save_best_only=True,
  save_weights_only=True,
  mode='auto',
  save_freq='epoch',
  option=None)

final_model_history = final_model.fit(
    [X_train['summary'], X_train['review']],
    y_train,
    batch_size=128,
    epochs=100,
    validation_data=([X_val['summary'], X_val['review']], y_val),
    callbacks=[save_best, early_stop]);
# Out:
# Epoch 1/100
# 1795/1795 [==============================] - 333s 181ms/step - loss: 0.5429 - accuracy: 0.7684 - val_loss: 0.4904 - val_accuracy: 0.7693
#
# Epoch 00001: val_loss improved from inf to 0.49040, saving model to Final_Model_weight.hdf5
# Epoch 2/100
# 1795/1795 [==============================] - 325s 181ms/step - loss: 0.4851 - accuracy: 0.7724 - val_loss: 0.4734 - val_accuracy: 0.7828
#
# Epoch 00002: val_loss improved from 0.49040 to 0.47336, saving model to Final_Model_weight.hdf5
# Epoch 3/100
# 1795/1795 [==============================] - 325s 181ms/step - loss: 0.4693 - accuracy: 0.7842 - val_loss: 0.4688 - val_accuracy: 0.7845
#
# Epoch 00003: val_loss improved from 0.47336 to 0.46882, saving model to Final_Model_weight.hdf5
# Epoch 4/100
# 1795/1795 [==============================] - 326s 182ms/step - loss: 0.4612 - accuracy: 0.7898 - val_loss: 0.4609 - val_accuracy: 0.7943
#
# Epoch 00004: val_loss improved from 0.46882 to 0.46091, saving model to Final_Model_weight.hdf5
# Epoch 5/100
# 1795/1795 [==============================] - 324s 181ms/step - loss: 0.4530 - accuracy: 0.7956 - val_loss: 0.4523 - val_accuracy: 0.7944
#
# Epoch 00005: val_loss improved from 0.46091 to 0.45226, saving model to Final_Model_weight.hdf5
# Epoch 6/100
# 1795/1795 [==============================] - 326s 181ms/step - loss: 0.4477 - accuracy: 0.7989 - val_loss: 0.4485 - val_accuracy: 0.7986
#
# Epoch 00006: val_loss improved from 0.45226 to 0.44848, saving model to Final_Model_weight.hdf5
# Epoch 7/100
# 1795/1795 [==============================] - 327s 182ms/step - loss: 0.4428 - accuracy: 0.8023 - val_loss: 0.4476 - val_accuracy: 0.7984
#
# Epoch 00007: val_loss improved from 0.44848 to 0.44759, saving model to Final_Model_weight.hdf5
# Epoch 8/100
# 1795/1795 [==============================] - 326s 182ms/step - loss: 0.4405 - accuracy: 0.8028 - val_loss: 0.4517 - val_accuracy: 0.8001
#
# Epoch 00008: val_loss did not improve from 0.44759
# Epoch 9/100
# 1795/1795 [==============================] - 324s 181ms/step - loss: 0.4384 - accuracy: 0.8045 - val_loss: 0.4475 - val_accuracy: 0.7999
#
# Epoch 00009: val_loss improved from 0.44759 to 0.44751, saving model to Final_Model_weight.hdf5
# Epoch 10/100
# 1795/1795 [==============================] - 323s 180ms/step - loss: 0.4330 - accuracy: 0.8066 - val_loss: 0.4505 - val_accuracy: 0.8001
#
# Epoch 00010: val_loss did not improve from 0.44751
# Epoch 11/100
# 1795/1795 [==============================] - 324s 180ms/step - loss: 0.4321 - accuracy: 0.8074 - val_loss: 0.4477 - val_accuracy: 0.8005
#
# Epoch 00011: val_loss did not improve from 0.44751
# Epoch 12/100
# 1795/1795 [==============================] - 325s 181ms/step - loss: 0.4306 - accuracy: 0.8089 - val_loss: 0.4430 - val_accuracy: 0.8026
#
# Epoch 00012: val_loss improved from 0.44751 to 0.44298, saving model to Final_Model_weight.hdf5
# Epoch 13/100
# 1795/1795 [==============================] - 323s 180ms/step - loss: 0.4273 - accuracy: 0.8095 - val_loss: 0.4480 - val_accuracy: 0.7988
#
# Epoch 00013: val_loss did not improve from 0.44298
# Epoch 14/100
# 1795/1795 [==============================] - 322s 179ms/step - loss: 0.4271 - accuracy: 0.8108 - val_loss: 0.4478 - val_accuracy: 0.8017
#
# Epoch 00014: val_loss did not improve from 0.44298
# Epoch 15/100
# 1795/1795 [==============================] - 321s 179ms/step - loss: 0.4267 - accuracy: 0.8099 - val_loss: 0.4458 - val_accuracy: 0.7988
#
# Epoch 00015: val_loss did not improve from 0.44298
# Epoch 16/100
# 1795/1795 [==============================] - 322s 179ms/step - loss: 0.4279 - accuracy: 0.8096 - val_loss: 0.4428 - val_accuracy: 0.8021
#
# Epoch 00016: val_loss improved from 0.44298 to 0.44278, saving model to Final_Model_weight.hdf5
# Epoch 17/100
# 1795/1795 [==============================] - 321s 179ms/step - loss: 0.4251 - accuracy: 0.8119 - val_loss: 0.4448 - val_accuracy: 0.7989
#
# Epoch 00017: val_loss did not improve from 0.44278
# Epoch 18/100
# 1795/1795 [==============================] - 322s 180ms/step - loss: 0.4237 - accuracy: 0.8127 - val_loss: 0.4421 - val_accuracy: 0.8017
#
# Epoch 00018: val_loss improved from 0.44278 to 0.44211, saving model to Final_Model_weight.hdf5
# Epoch 19/100
# 1795/1795 [==============================] - 323s 180ms/step - loss: 0.4242 - accuracy: 0.8097 - val_loss: 0.4432 - val_accuracy: 0.8012
#
# Epoch 00019: val_loss did not improve from 0.44211
# Epoch 20/100
# 1795/1795 [==============================] - 323s 180ms/step - loss: 0.4250 - accuracy: 0.8111 - val_loss: 0.4419 - val_accuracy: 0.8018
#
# Epoch 00020: val_loss improved from 0.44211 to 0.44188, saving model to Final_Model_weight.hdf5
# Epoch 21/100
# 1795/1795 [==============================] - 323s 180ms/step - loss: 0.4226 - accuracy: 0.8120 - val_loss: 0.4469 - val_accuracy: 0.8010
#
# Epoch 00021: val_loss did not improve from 0.44188
# Epoch 22/100
# 1795/1795 [==============================] - 323s 180ms/step - loss: 0.4218 - accuracy: 0.8118 - val_loss: 0.4430 - val_accuracy: 0.8027
#
# Epoch 00022: val_loss did not improve from 0.44188
# Epoch 23/100
# 1795/1795 [==============================] - 324s 180ms/step - loss: 0.4222 - accuracy: 0.8125 - val_loss: 0.4436 - val_accuracy: 0.8023
#
# Epoch 00023: val_loss did not improve from 0.44188
# Epoch 24/100
# 1795/1795 [==============================] - 324s 181ms/step - loss: 0.4187 - accuracy: 0.8149 - val_loss: 0.4441 - val_accuracy: 0.8015
#
# Epoch 00024: val_loss did not improve from 0.44188
# Epoch 25/100
# 1795/1795 [==============================] - 323s 180ms/step - loss: 0.4200 - accuracy: 0.8134 - val_loss: 0.4407 - val_accuracy: 0.8023
#
# Epoch 00025: val_loss improved from 0.44188 to 0.44073, saving model to Final_Model_weight.hdf5
# Epoch 26/100
# 1795/1795 [==============================] - 324s 180ms/step - loss: 0.4221 - accuracy: 0.8123 - val_loss: 0.4431 - val_accuracy: 0.8021
#
# Epoch 00026: val_loss did not improve from 0.44073
# Epoch 27/100
# 1795/1795 [==============================] - 325s 181ms/step - loss: 0.4198 - accuracy: 0.8136 - val_loss: 0.4405 - val_accuracy: 0.8030
#
# Epoch 00027: val_loss improved from 0.44073 to 0.44049, saving model to Final_Model_weight.hdf5
# Epoch 28/100
# 1795/1795 [==============================] - 325s 181ms/step - loss: 0.4187 - accuracy: 0.8135 - val_loss: 0.4507 - val_accuracy: 0.7992
#
# Epoch 00028: val_loss did not improve from 0.44049
# Epoch 29/100
# 1795/1795 [==============================] - 324s 180ms/step - loss: 0.4210 - accuracy: 0.8130 - val_loss: 0.4546 - val_accuracy: 0.7949
#
# Epoch 00029: val_loss did not improve from 0.44049
# Epoch 30/100
# 1795/1795 [==============================] - 323s 180ms/step - loss: 0.4181 - accuracy: 0.8151 - val_loss: 0.4426 - val_accuracy: 0.8016
#
# Epoch 00030: val_loss did not improve from 0.44049
# Epoch 31/100
# 1795/1795 [==============================] - 323s 180ms/step - loss: 0.4174 - accuracy: 0.8155 - val_loss: 0.4411 - val_accuracy: 0.8023
#
# Epoch 00031: val_loss did not improve from 0.44049
# Epoch 32/100
# 1795/1795 [==============================] - 322s 179ms/step - loss: 0.4180 - accuracy: 0.8154 - val_loss: 0.4407 - val_accuracy: 0.8034
#
# Epoch 00032: val_loss did not improve from 0.44049
# Epoch 33/100
# 1795/1795 [==============================] - 322s 179ms/step - loss: 0.4172 - accuracy: 0.8140 - val_loss: 0.4492 - val_accuracy: 0.7999
#
# Epoch 00033: val_loss did not improve from 0.44049
# Epoch 34/100
# 1795/1795 [==============================] - 322s 179ms/step - loss: 0.4155 - accuracy: 0.8166 - val_loss: 0.4491 - val_accuracy: 0.8002
#
# Epoch 00034: val_loss did not improve from 0.44049
# Epoch 35/100
# 1795/1795 [==============================] - 321s 179ms/step - loss: 0.4156 - accuracy: 0.8174 - val_loss: 0.4414 - val_accuracy: 0.8025
#
# Epoch 00035: val_loss did not improve from 0.44049
# Epoch 36/100
# 1795/1795 [==============================] - 323s 180ms/step - loss: 0.4154 - accuracy: 0.8165 - val_loss: 0.4428 - val_accuracy: 0.8024
#
# Epoch 00036: val_loss did not improve from 0.44049
# Epoch 37/100
# 1795/1795 [==============================] - 323s 180ms/step - loss: 0.4133 - accuracy: 0.8167 - val_loss: 0.4419 - val_accuracy: 0.8018
#
# Epoch 00037: val_loss did not improve from 0.44049
# Epoch 00037: early stopping

# %%
# validation dataset accuracy, f1_score

# %%time
final_model.load_weights(file_path)
y_pred = final_model.predict([X_val['summary'], X_val['review']])
y_pred_class = np.array([1 if value > 0.5 else 0 for value in y_pred])

print('val accuracy:', accuracy_score(y_val, y_pred_class))
print('val f1_score:', f1_score(y_val, y_pred_class))
# Out:
# val accuracy: 0.8030140778854441
# val f1_score: 0.398180657516757
# CPU times: user 1min 51s, sys: 3.6 s, total: 1min 54s
# Wall time: 1min 30s

# %%
from sklearn.metrics import classification_report
print(classification_report(y_val, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.96      0.88     58910
#            1       0.67      0.28      0.40     17664
#
#     accuracy                           0.80     76574
#    macro avg       0.75      0.62      0.64     76574
# weighted avg       0.78      0.80      0.77     76574

# %%
final_model.save_weights(os.path.join(base_path, 'model_result', 'Final_Model_weight.hdf5'))

# %%
final_model.save(os.path.join(base_path, 'model_result', 'Final_Model.h5'))
show_history(final_model_history)

# %% [markdown]
# ### 5) Test dataset에 대한 결과 확인

# %%
y_pred_test = final_model.predict([X_test['summary'], X_test['review']])
y_pred_class_test = np.array([1 if value > 0.5 else 0 for value in y_pred_test])

print('test accuracy:', accuracy_score(y_test, y_pred_class_test))
print('test f1_score:', f1_score(y_test, y_pred_class_test))
# Out:
# test accuracy: 0.8025308851568418
# test f1_score: 0.39557101171203585

# %%
test_loss, test_acc = final_model.evaluate([X_test['summary'], X_test['review']], 
                                           y_test,
                                           verbose=2)
# Out:
# 2393/2393 - 101s - loss: 0.4423 - accuracy: 0.8025

# %%
print(classification_report(y_test, y_pred_class_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.96      0.88     58910
#            1       0.67      0.28      0.40     17664
#
#     accuracy                           0.80     76574
#    macro avg       0.74      0.62      0.64     76574
# weighted avg       0.78      0.80      0.77     76574

# %% [markdown]
# 최종 모델의 test 데이터셋에 대한 accuracy는 약 0.8025이고, f1 score는 약 0.4000이다. 기준모델에 비하면 성능이 꽤 좋아졌다.
